# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285387 sha256=8a8f89b5036f9165398cb1ac154315175f7c04452f8e94984c7fa8e381c71560
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import count, when, col,collect_list
from pyspark.sql.window import Window
import pyspark.sql.functions as F
spark=SparkSession.builder.appName('prjoect').getOrCreate()

# %%
df=spark.read.option('inferschema','true').option('header','true').csv('/content/2020_olympics_data.csv')

# %%
df.printSchema()

# %%
df.show()
# Out:
# +------------------+------+----+-----------+---+----+-----+-------------------+--------------------+-----+
# |              Name|Gender| Age|    Country|NOC|Year| City|              Sport|               Event|Medal|
# +------------------+------+----+-----------+---+----+-----+-------------------+--------------------+-----+
# |   AALERUD Katrine|     F|26.0|     Norway|NOR|2020|Tokyo|       Cycling Road|   Women's Road Race| None|
# |   AALERUD Katrine|     F|26.0|     Norway|NOR|2020|Tokyo|       Cycling Road|Women's Individua...| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics|    Men's All-Around| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics|Men's Floor Exercise| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics|  Men's Pommel Horse| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics|         Men's Rings| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics|         Men's Vault| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics| Men's Parallel Bars| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics|Men's Horizontal Bar| None|
# |       ABAD Nestor|     M|28.0|      Spain|ESP|2020|Tokyo|Artistic Gymnastics|          Men's Team| None|
# | ABAGNALE Giovanni|     M|26.0|      Italy|ITA|2020|Tokyo|             Rowing|     Men's Pair Team| None|
# |    ABALDE Alberto|     M|25.0|      Spain|ESP|2020|Tokyo|         Basketball|            Men Team| None|
# |     ABALDE Tamara|     F|32.0|      Spain|ESP|2020|Tokyo|         Basketball|          Women Team| None|
# |         ABALO Luc|     M|36.0|     France|FRA|2020|Tokyo|           Handball|            Men Team| Gold|
# |      ABAROA Cesar|     M|24.0|      Chile|CHI|2020|Tokyo|             Rowing|Lightweight Men's...| None|
# |     ABASS Abobakr|     M|22.0|      Sudan|SUD|2020|Tokyo|           Swimming|Men's 100m Breast...| None|
# |ABBAGNALE Vincenzo|     M|28.0|      Italy|ITA|2020|Tokyo|             Rowing|     Men's Pair Team| None|
# |  ABBASALI Hamideh|     F|31.0|       Iran|IRI|2020|Tokyo|             Karate|Women's Kumite +61kg| None|
# |     ABBASOV Islam|     M|25.0| Azerbaijan|AZE|2020|Tokyo|          Wrestling|Men's Greco-Roman...| None|
# |      ABBINGH Lois|     F|28.0|Netherlands|NED|2020|Tokyo|           Handball|          Women Team| None|
# +------------------+------+----+-----------+---+----+-----+-------------------+--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # 1. DataFrame showing Medal Count for each country

# %%
df.groupBy('Country').agg(
    count(when(df['Medal']=='Gold',True)).alias('Gold'),
    count(when(df['Medal']=='Silver',True)).alias('Silver'),
    count(when(df['Medal']=='Bronze',True)).alias('Bronze'),
    count(when(df['Medal']!='None',True)).alias('Total')).orderBy('Total',ascending=False).show()
# Out:
# +-------------+----+------+------+-----+
# |      Country|Gold|Silver|Bronze|Total|
# +-------------+----+------+------+-----+
# |United States| 113|   110|    75|  298|
# |       Russia|  41|    80|    28|  149|
# |       France|  65|    42|    34|  141|
# |Great Britain|  41|    43|    57|  141|
# |        China|  59|    49|    33|  141|
# |        Japan|  68|    41|    22|  131|
# |    Australia|  36|    28|    67|  131|
# |       Canada|  36|    11|    38|   85|
# |      Germany|  21|    26|    34|   81|
# |        Italy|  22|    17|    37|   76|
# |  Netherlands|  33|    22|    17|   72|
# |        Spain|   4|    44|    22|   70|
# |  New Zealand|  29|    28|     8|   65|
# |       Brazil|  29|    17|     9|   55|
# |      Hungary|   9|     7|    35|   51|
# |    Argentina|   0|    18|    25|   43|
# |  South Korea|  14|     7|    17|   38|
# |       Poland|  14|    14|     8|   36|
# |       Serbia|  15|     1|    19|   35|
# |       Sweden|   6|    28|     0|   34|
# +-------------+----+------+------+-----+
# only showing top 20 rows

# %% [markdown]
# # 2.  DataFrames for each sport showing medal counts for each country

# %%
unique_sports = [row['Sport'] for row in df.select('Sport').distinct().collect()]

# Create an empty dictionary to store DataFrames for each sport
sport_dataframes = {}

# Iterate through each sport
for sport in unique_sports:
    # Filter the DataFrame for the current sport
    sport_df = df.filter(df["Sport"] == sport)

    # Group the filtered DataFrame by "Sport" and "Country" and calculate medal counts
    result_df = sport_df.groupBy("Sport", "Country").agg(
        count(when(sport_df["Medal"] == "Gold", True)).alias("Gold"),
        count(when(sport_df["Medal"] == "Silver", True)).alias("Silver"),
        count(when(sport_df["Medal"] == "Bronze", True)).alias("Bronze"),
        count(when(df['Medal']!='None',True)).alias('Total')
    )

    # Define a Window specification for ranking within the sport
    window_spec = Window.partitionBy("Sport").orderBy(
        col("Gold").desc(), col("Silver").desc(), col("Bronze").desc(), col("Total").desc()
    )

    # Add a "Rank" column based on medal counts within the sport
    result_df = result_df.withColumn("Rank", F.row_number().over(window_spec))

    # Filter for the top 10 countries in the sport
    result_df = result_df.filter(col("Rank") <= 10)
    result_df.show()
    # Store the result DataFrame in the dictionary using the sport name as the key
    sport_dataframes[sport] = result_df

# Now you have a dictionary 'sport_dataframes' with DataFrames for the top 10 countries in each sport
# You can access each sport's DataFrame using sport_dataframes[sport_name]
# For example, to access the top 10 countries in "Swimming," use sport_dataframes["Swimming"].show()
# Out:
# +------+--------------+----+------+------+-----+----+
# | Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +------+--------------+----+------+------+-----+----+
# |Tennis|        Russia|   2|     3|     0|    5|   1|
# |Tennis|       Croatia|   2|     2|     0|    4|   2|
# |Tennis|Czech Republic|   2|     1|     0|    3|   3|
# |Tennis|   Switzerland|   1|     2|     0|    3|   4|
# |Tennis|       Germany|   1|     0|     0|    1|   5|
# |Tennis|   New Zealand|   0|     0|     2|    2|   6|
# |Tennis|     Australia|   0|     0|     2|    2|   7|
# |Tennis|        Brazil|   0|     0|     2|    2|   8|
# |Tennis|         Spain|   0|     0|     1|    1|   9|
# |Tennis|       Ukraine|   0|     0|     1|    1|  10|
# +------+--------------+----+------+------+-----+----+
#
# +------+-------------+----+------+------+-----+----+
# | Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +------+-------------+----+------+------+-----+----+
# |Boxing|         Cuba|   4|     0|     1|    5|   1|
# |Boxing|Great Britain|   2|     2|     2|    6|   2|
# |Boxing|       Russia|   1|     1|     4|    6|   3|
# |Boxing|       Brazil|   1|     1|     1|    3|   4|
# |Boxing|       Turkey|   1|     1|     0|    2|   5|
# |Boxing|        Japan|   1|     0|     2|    3|   6|
# |Boxing|      Ireland|   1|     0|     1|    2|   7|
# |Boxing|   Uzbekistan|   1|     0|     0|    1|   8|
# |Boxing|     Bulgaria|   1|     0|     0|    1|   9|
# |Boxing|United States|   0|     3|     1|    4|  10|
# +------+-------------+----+------+------+-----+----+
#
# +-----------------+-----------+----+------+------+-----+----+
# |            Sport|    Country|Gold|Silver|Bronze|Total|Rank|
# +-----------------+-----------+----+------+------+-----+----+
# |Marathon Swimming|     Brazil|   1|     0|     0|    1|   1|
# |Marathon Swimming|    Germany|   1|     0|     0|    1|   2|
# |Marathon Swimming|    Hungary|   0|     1|     0|    1|   3|
# |Marathon Swimming|Netherlands|   0|     1|     0|    1|   4|
# |Marathon Swimming|      Italy|   0|     0|     1|    1|   5|
# |Marathon Swimming|  Australia|   0|     0|     1|    1|   6|
# |Marathon Swimming|   Portugal|   0|     0|     0|    0|   7|
# |Marathon Swimming|     Russia|   0|     0|     0|    0|   8|
# |Marathon Swimming|     Israel|   0|     0|     0|    0|   9|
# |Marathon Swimming|  Argentina|   0|     0|     0|    0|  10|
# +-----------------+-----------+----+------+------+-----+----+
#
# +-----+--------------+----+------+------+-----+----+
# |Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +-----+--------------+----+------+------+-----+----+
# | Golf| United States|   2|     0|     0|    2|   1|
# | Golf|         Japan|   0|     1|     0|    1|   2|
# | Golf|      Slovakia|   0|     1|     0|    1|   3|
# | Golf|   New Zealand|   0|     0|     1|    1|   4|
# | Golf|Chinese Taipei|   0|     0|     1|    1|   5|
# | Golf|   Puerto Rico|   0|     0|     0|    0|   6|
# | Golf|       Ecuador|   0|     0|     0|    0|   7|
# | Golf|  South Africa|   0|     0|     0|    0|   8|
# | Golf|      Malaysia|   0|     0|     0|    0|   9|
# | Golf|       Ireland|   0|     0|     0|    0|  10|
# +-----+--------------+----+------+------+-----+----+
#
# +------+-----------+----+------+------+-----+----+
# | Sport|    Country|Gold|Silver|Bronze|Total|Rank|
# +------+-----------+----+------+------+-----+----+
# |Rowing|New Zealand|  12|    11|     0|   23|   1|
# |Rowing|     Canada|   9|     0|     2|   11|   2|
# |Rowing|  Australia|   8|     0|     8|   16|   3|
# |Rowing|Netherlands|   4|     6|     4|   14|   4|
# |Rowing|      China|   4|     0|    11|   15|   5|
# |Rowing|    Romania|   2|     6|     0|    8|   6|
# |Rowing|     France|   2|     2|     0|    4|   7|
# |Rowing|      Italy|   2|     0|     6|    8|   8|
# |Rowing|    Ireland|   2|     0|     4|    6|   9|
# |Rowing|    Croatia|   2|     0|     1|    3|  10|
# +------+-----------+----+------+------+-----+----+
#
# +-----------------+------------------+----+------+------+-----+----+
# |            Sport|           Country|Gold|Silver|Bronze|Total|Rank|
# +-----------------+------------------+----+------+------+-----+----+
# |Baseball/Softball|             Japan|  39|     0|     0|   39|   1|
# |Baseball/Softball|     United States|   0|    39|     0|   39|   2|
# |Baseball/Softball|Dominican Republic|   0|     0|    24|   24|   3|
# |Baseball/Softball|            Canada|   0|     0|    15|   15|   4|
# |Baseball/Softball|            Mexico|   0|     0|     0|    0|   5|
# |Baseball/Softball|         Australia|   0|     0|     0|    0|   6|
# |Baseball/Softball|             Italy|   0|     0|     0|    0|   7|
# |Baseball/Softball|            Israel|   0|     0|     0|    0|   8|
# |Baseball/Softball|       South Korea|   0|     0|     0|    0|   9|
# +-----------------+------------------+----+------+------+-----+----+
#
# +-----+--------------+----+------+------+-----+----+
# |Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +-----+--------------+----+------+------+-----+----+
# | Judo|        France|  12|     3|     3|   18|   1|
# | Judo|         Japan|   9|    13|     1|   23|   2|
# | Judo|        Kosovo|   2|     0|     0|    2|   3|
# | Judo|       Georgia|   1|     3|     0|    4|   4|
# | Judo|Czech Republic|   1|     0|     0|    1|   5|
# | Judo|       Germany|   0|     1|    13|   14|   6|
# | Judo|      Mongolia|   0|     1|     2|    3|   7|
# | Judo|   South Korea|   0|     1|     2|    3|   8|
# | Judo|       Austria|   0|     1|     1|    2|   9|
# | Judo|          Cuba|   0|     1|     0|    1|  10|
# +-----+--------------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |  Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |Sailing|Great Britain|   5|     2|     1|    8|   1|
# |Sailing|    Australia|   3|     0|     0|    3|   2|
# |Sailing|       Brazil|   2|     0|     0|    2|   3|
# |Sailing|        Italy|   2|     0|     0|    2|   4|
# |Sailing|  Netherlands|   1|     0|     3|    4|   5|
# |Sailing|        China|   1|     0|     1|    2|   6|
# |Sailing|      Denmark|   1|     0|     0|    1|   7|
# |Sailing|       Sweden|   0|     3|     0|    3|   8|
# |Sailing|      Germany|   0|     2|     4|    6|   9|
# |Sailing|       France|   0|     2|     2|    4|  10|
# +-------+-------------+----+------+------+-----+----+
#
# +--------+-------------+----+------+------+-----+----+
# |   Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +--------+-------------+----+------+------+-----+----+
# |Swimming|United States|  22|    22|    15|   59|   1|
# |Swimming|    Australia|  20|     3|    30|   53|   2|
# |Swimming|Great Britain|  12|     7|     1|   20|   3|
# |Swimming|        China|   8|     5|     1|   14|   4|
# |Swimming|       Russia|   2|     7|     1|   10|   5|
# |Swimming|        Japan|   2|     1|     0|    3|   6|
# |Swimming|       Canada|   1|     7|     7|   15|   7|
# |Swimming|      Hungary|   1|     1|     0|    2|   8|
# |Swimming| South Africa|   1|     1|     0|    2|   9|
# |Swimming|      Tunisia|   1|     0|     0|    1|  10|
# +--------+-------------+----+------+------+-----+----+
#
# +--------------------+-------------+----+------+------+-----+----+
# |               Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +--------------------+-------------+----+------+------+-----+----+
# |Cycling BMX Frees...|Great Britain|   1|     0|     1|    2|   1|
# |Cycling BMX Frees...|    Australia|   1|     0|     0|    1|   2|
# |Cycling BMX Frees...|    Venezuela|   0|     1|     0|    1|   3|
# |Cycling BMX Frees...|United States|   0|     1|     0|    1|   4|
# |Cycling BMX Frees...|  Switzerland|   0|     0|     1|    1|   5|
# |Cycling BMX Frees...|        Chile|   0|     0|     0|    0|   6|
# |Cycling BMX Frees...|      Germany|   0|     0|     0|    0|   7|
# |Cycling BMX Frees...|       France|   0|     0|     0|    0|   8|
# |Cycling BMX Frees...|       Russia|   0|     0|     0|    0|   9|
# |Cycling BMX Frees...|        Japan|   0|     0|     0|    0|  10|
# +--------------------+-------------+----+------+------+-----+----+
#
# +----------+-------------+----+------+------+-----+----+
# |     Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +----------+-------------+----+------+------+-----+----+
# |Basketball|United States|  24|     0|     0|   24|   1|
# |Basketball|       France|   0|    12|    12|   24|   2|
# |Basketball|        Japan|   0|    12|     0|   12|   3|
# |Basketball|    Australia|   0|     0|    12|   12|   4|
# |Basketball|    Argentina|   0|     0|     0|    0|   5|
# |Basketball|      Nigeria|   0|     0|     0|    0|   6|
# |Basketball|  Puerto Rico|   0|     0|     0|    0|   7|
# |Basketball|       Canada|   0|     0|     0|    0|   8|
# |Basketball|        China|   0|     0|     0|    0|   9|
# |Basketball|        Spain|   0|     0|     0|    0|  10|
# +----------+-------------+----+------+------+-----+----+
#
# +--------+-----------+----+------+------+-----+----+
# |   Sport|    Country|Gold|Silver|Bronze|Total|Rank|
# +--------+-----------+----+------+------+-----+----+
# |Handball|     France|  32|     0|     0|   32|   1|
# |Handball|    Denmark|   0|    15|     0|   15|   2|
# |Handball|     Russia|   0|    15|     0|   15|   3|
# |Handball|      Spain|   0|     0|    16|   16|   4|
# |Handball|     Norway|   0|     0|    15|   15|   5|
# |Handball|     Angola|   0|     0|     0|    0|   6|
# |Handball|South Korea|   0|     0|     0|    0|   7|
# |Handball|    Bahrain|   0|     0|     0|    0|   8|
# |Handball|  Argentina|   0|     0|     0|    0|   9|
# |Handball|      Egypt|   0|     0|     0|    0|  10|
# +--------+-----------+----+------+------+-----+----+
#
# +-------------------+----------+----+------+------+-----+----+
# |              Sport|   Country|Gold|Silver|Bronze|Total|Rank|
# +-------------------+----------+----+------+------+-----+----+
# |Rhythmic Gymnastics|  Bulgaria|   5|     0|     0|    5|   1|
# |Rhythmic Gymnastics|    Israel|   1|     0|     0|    1|   2|
# |Rhythmic Gymnastics|    Russia|   0|     6|     0|    6|   3|
# |Rhythmic Gymnastics|     Italy|   0|     0|     5|    5|   4|
# |Rhythmic Gymnastics|   Belarus|   0|     0|     1|    1|   5|
# |Rhythmic Gymnastics|Azerbaijan|   0|     0|     0|    0|   6|
# |Rhythmic Gymnastics|   Georgia|   0|     0|     0|    0|   7|
# |Rhythmic Gymnastics|     China|   0|     0|     0|    0|   8|
# |Rhythmic Gymnastics|     Egypt|   0|     0|     0|    0|   9|
# |Rhythmic Gymnastics| Australia|   0|     0|     0|    0|  10|
# +-------------------+----------+----+------+------+-----+----+
#
# +------+----------+----+------+------+-----+----+
# | Sport|   Country|Gold|Silver|Bronze|Total|Rank|
# +------+----------+----+------+------+-----+----+
# |Karate|     Japan|   1|     1|     1|    3|   1|
# |Karate|     Spain|   1|     1|     0|    2|   2|
# |Karate|     Italy|   1|     0|     1|    2|   3|
# |Karate|     Egypt|   1|     0|     1|    2|   4|
# |Karate|    France|   1|     0|     0|    1|   5|
# |Karate|    Serbia|   1|     0|     0|    1|   6|
# |Karate|      Iran|   1|     0|     0|    1|   7|
# |Karate|  Bulgaria|   1|     0|     0|    1|   8|
# |Karate|Azerbaijan|   0|     2|     0|    2|   9|
# |Karate|    Turkey|   0|     1|     3|    4|  10|
# +------+----------+----+------+------+-----+----+
#
# +---------+-------------+----+------+------+-----+----+
# |    Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +---------+-------------+----+------+------+-----+----+
# |Triathlon|Great Britain|   5|     2|     0|    7|   1|
# |Triathlon|       Norway|   1|     0|     0|    1|   2|
# |Triathlon|      Bermuda|   1|     0|     0|    1|   3|
# |Triathlon|United States|   0|     5|     1|    6|   4|
# |Triathlon|       France|   0|     0|     5|    5|   5|
# |Triathlon|  New Zealand|   0|     0|     1|    1|   6|
# |Triathlon|      Estonia|   0|     0|     0|    0|   7|
# |Triathlon|      Belgium|   0|     0|     0|    0|   8|
# |Triathlon|      Austria|   0|     0|     0|    0|   9|
# |Triathlon|   Luxembourg|   0|     0|     0|    0|  10|
# +---------+-------------+----+------+------+-----+----+
#
# +---------+--------------+----+------+------+-----+----+
# |    Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +---------+--------------+----+------+------+-----+----+
# |Badminton|         China|   3|     7|     0|   10|   1|
# |Badminton|Chinese Taipei|   2|     1|     0|    3|   2|
# |Badminton|     Indonesia|   2|     0|     1|    3|   3|
# |Badminton|       Denmark|   1|     0|     0|    1|   4|
# |Badminton|      Malaysia|   0|     0|     2|    2|   5|
# |Badminton|         Japan|   0|     0|     2|    2|   6|
# |Badminton|   South Korea|   0|     0|     2|    2|   7|
# |Badminton|         India|   0|     0|     1|    1|   8|
# |Badminton|        Sweden|   0|     0|     0|    0|   9|
# |Badminton|       Ukraine|   0|     0|     0|    0|  10|
# +---------+--------------+----+------+------+-----+----+
#
# +------------+-------------+----+------+------+-----+----+
# |       Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +------------+-------------+----+------+------+-----+----+
# |Canoe Sprint|      Hungary|   6|     2|     2|   10|   1|
# |Canoe Sprint|      Germany|   4|     2|     2|    8|   2|
# |Canoe Sprint|  New Zealand|   4|     0|     0|    4|   3|
# |Canoe Sprint|        China|   2|     3|     0|    5|   4|
# |Canoe Sprint|    Australia|   2|     0|     0|    2|   5|
# |Canoe Sprint|         Cuba|   2|     0|     0|    2|   6|
# |Canoe Sprint|       Brazil|   1|     0|     0|    1|   7|
# |Canoe Sprint|United States|   1|     0|     0|    1|   8|
# |Canoe Sprint|        Spain|   0|     5|     0|    5|   9|
# |Canoe Sprint|      Belarus|   0|     4|     0|    4|  10|
# +------------+-------------+----+------+------+-----+----+
#
# +---------+-------------+----+------+------+-----+----+
# |    Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +---------+-------------+----+------+------+-----+----+
# |Athletics|United States|  21|    17|    14|   52|   1|
# |Athletics|       Poland|  14|     6|     3|   23|   2|
# |Athletics|        Italy|  10|     0|     0|   10|   3|
# |Athletics|      Jamaica|   9|     1|    11|   21|   4|
# |Athletics|        Kenya|   4|     4|     2|   10|   5|
# |Athletics|  Netherlands|   2|     8|     3|   13|   6|
# |Athletics|        China|   2|     2|     1|    5|   7|
# |Athletics|       Canada|   2|     1|     9|   12|   8|
# |Athletics|       Uganda|   2|     1|     1|    4|   9|
# |Athletics|       Norway|   2|     1|     0|    3|  10|
# +---------+-------------+----+------+------+-----+----+
#
# +-------------+-------------+----+------+------+-----+----+
# |        Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +-------------+-------------+----+------+------+-----+----+
# |Cycling Track|      Germany|   6|     3|     0|    9|   1|
# |Cycling Track|  Netherlands|   6|     1|     2|    9|   2|
# |Cycling Track|        Italy|   6|     0|     1|    7|   3|
# |Cycling Track|Great Britain|   4|    12|     1|   17|   4|
# |Cycling Track|        China|   3|     0|     0|    3|   5|
# |Cycling Track|      Denmark|   2|     8|     0|   10|   6|
# |Cycling Track|United States|   1|     0|     5|    6|   7|
# |Cycling Track|       Canada|   1|     0|     1|    2|   8|
# |Cycling Track|  New Zealand|   0|     2|     0|    2|   9|
# |Cycling Track|        Japan|   0|     1|     0|    1|  10|
# +-------------+-------------+----+------+------+-----+----+
#
# +----------------+-------------+----+------+------+-----+----+
# |           Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +----------------+-------------+----+------+------+-----+----+
# |Beach Volleyball|       Norway|   2|     0|     0|    2|   1|
# |Beach Volleyball|United States|   2|     0|     0|    2|   2|
# |Beach Volleyball|       Russia|   0|     2|     0|    2|   3|
# |Beach Volleyball|    Australia|   0|     2|     0|    2|   4|
# |Beach Volleyball|        Qatar|   0|     0|     2|    2|   5|
# |Beach Volleyball|  Switzerland|   0|     0|     2|    2|   6|
# |Beach Volleyball|       Brazil|   0|     0|     0|    0|   7|
# |Beach Volleyball|        Chile|   0|     0|     0|    0|   8|
# |Beach Volleyball|  Netherlands|   0|     0|     0|    0|   9|
# |Beach Volleyball|      Morocco|   0|     0|     0|    0|  10|
# +----------------+-------------+----+------+------+-----+----+
#
# +-------------+-------------+----+------+------+-----+----+
# |        Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +-------------+-------------+----+------+------+-----+----+
# |Skateboarding|        Japan|   3|     1|     1|    5|   1|
# |Skateboarding|    Australia|   1|     0|     0|    1|   2|
# |Skateboarding|       Brazil|   0|     3|     0|    3|   3|
# |Skateboarding|United States|   0|     0|     2|    2|   4|
# |Skateboarding|Great Britain|   0|     0|     1|    1|   5|
# |Skateboarding|        Spain|   0|     0|     0|    0|   6|
# |Skateboarding|      Belgium|   0|     0|     0|    0|   7|
# |Skateboarding| South Africa|   0|     0|     0|    0|   8|
# |Skateboarding|         Peru|   0|     0|     0|    0|   9|
# |Skateboarding|        Italy|   0|     0|     0|    0|  10|
# +-------------+-------------+----+------+------+-----+----+
#
# +----------+-------------+----+------+------+-----+----+
# |     Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +----------+-------------+----+------+------+-----+----+
# |Equestrian|      Germany|   6|     1|     0|    7|   1|
# |Equestrian|Great Britain|   5|     1|     5|   11|   2|
# |Equestrian|       Sweden|   4|     1|     0|    5|   3|
# |Equestrian|United States|   0|     7|     0|    7|   4|
# |Equestrian|    Australia|   0|     4|     1|    5|   5|
# |Equestrian|      Belgium|   0|     0|     4|    4|   6|
# |Equestrian|       France|   0|     0|     3|    3|   7|
# |Equestrian|  Netherlands|   0|     0|     1|    1|   8|
# |Equestrian|       Jordan|   0|     0|     0|    0|   9|
# |Equestrian|      Finland|   0|     0|     0|    0|  10|
# +----------+-------------+----+------+------+-----+----+
#
# +--------+--------------+----+------+------+-----+----+
# |   Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +--------+--------------+----+------+------+-----+----+
# |Shooting|         China|   6|     1|     6|   13|   1|
# |Shooting| United States|   3|     3|     2|    8|   2|
# |Shooting|        Russia|   2|     5|     3|   10|   3|
# |Shooting|         Spain|   2|     0|     0|    2|   4|
# |Shooting|Czech Republic|   1|     1|     0|    2|   5|
# |Shooting|   Switzerland|   1|     0|     1|    2|   6|
# |Shooting|      Slovakia|   1|     0|     0|    1|   7|
# |Shooting|        France|   1|     0|     0|    1|   8|
# |Shooting|          Iran|   1|     0|     0|    1|   9|
# |Shooting|    San Marino|   0|     2|     1|    3|  10|
# +--------+--------------+----+------+------+-----+----+
#
# +------+-------------+----+------+------+-----+----+
# | Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +------+-------------+----+------+------+-----+----+
# |Diving|        China|  10|     6|     0|   16|   1|
# |Diving|Great Britain|   2|     0|     2|    4|   2|
# |Diving|United States|   0|     4|     1|    5|   3|
# |Diving|       Canada|   0|     2|     0|    2|   4|
# |Diving|      Germany|   0|     0|     4|    4|   5|
# |Diving|       Russia|   0|     0|     2|    2|   6|
# |Diving|       Mexico|   0|     0|     2|    2|   7|
# |Diving|    Australia|   0|     0|     1|    1|   8|
# |Diving|       Brazil|   0|     0|     0|    0|   9|
# |Diving|      Jamaica|   0|     0|     0|    0|  10|
# +------+-------------+----+------+------+-----+----+
#
# +------------+--------------+----+------+------+-----+----+
# |       Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +------------+--------------+----+------+------+-----+----+
# |Canoe Slalom|Czech Republic|   1|     1|     0|    2|   1|
# |Canoe Slalom|       Germany|   1|     0|     3|    4|   2|
# |Canoe Slalom|     Australia|   1|     0|     1|    2|   3|
# |Canoe Slalom|      Slovenia|   1|     0|     0|    1|   4|
# |Canoe Slalom|      Slovakia|   0|     1|     0|    1|   5|
# |Canoe Slalom| Great Britain|   0|     1|     0|    1|   6|
# |Canoe Slalom|         Spain|   0|     1|     0|    1|   7|
# |Canoe Slalom|   Netherlands|   0|     0|     0|    0|   8|
# |Canoe Slalom|  Cook Islands|   0|     0|     0|    0|   9|
# |Canoe Slalom|        Canada|   0|     0|     0|    0|  10|
# +------------+--------------+----+------+------+-----+----+
#
# +------------+-----------+----+------+------+-----+----+
# |       Sport|    Country|Gold|Silver|Bronze|Total|Rank|
# +------------+-----------+----+------+------+-----+----+
# |Rugby Sevens|New Zealand|  13|    13|     0|   26|   1|
# |Rugby Sevens|       Fiji|  13|     0|    13|   26|   2|
# |Rugby Sevens|     France|   0|    13|     0|   13|   3|
# |Rugby Sevens|  Argentina|   0|     0|    13|   13|   4|
# |Rugby Sevens|    Ireland|   0|     0|     0|    0|   5|
# |Rugby Sevens|South Korea|   0|     0|     0|    0|   6|
# |Rugby Sevens|      Kenya|   0|     0|     0|    0|   7|
# |Rugby Sevens|     Russia|   0|     0|     0|    0|   8|
# |Rugby Sevens|      China|   0|     0|     0|    0|   9|
# |Rugby Sevens|      Japan|   0|     0|     0|    0|  10|
# +------------+-----------+----+------+------+-----+----+
#
# +-------------------+-------------+----+------+------+-----+----+
# |              Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +-------------------+-------------+----+------+------+-----+----+
# |Artistic Gymnastics|       Russia|   8|     2|     4|   14|   1|
# |Artistic Gymnastics|        China|   3|     3|     5|   11|   2|
# |Artistic Gymnastics|United States|   2|     5|     2|    9|   3|
# |Artistic Gymnastics|        Japan|   2|     4|     2|    8|   4|
# |Artistic Gymnastics|       Brazil|   1|     1|     0|    2|   5|
# |Artistic Gymnastics|Great Britain|   1|     0|     4|    5|   6|
# |Artistic Gymnastics|  South Korea|   1|     0|     1|    2|   7|
# |Artistic Gymnastics|      Belgium|   1|     0|     0|    1|   8|
# |Artistic Gymnastics|       Israel|   1|     0|     0|    1|   9|
# |Artistic Gymnastics|        Italy|   0|     1|     0|    1|  10|
# +-------------------+-------------+----+------+------+-----+----+
#
# +--------------------+-------------+----+------+------+-----+----+
# |               Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +--------------------+-------------+----+------+------+-----+----+
# |Cycling Mountain ...|  Switzerland|   1|     2|     1|    4|   1|
# |Cycling Mountain ...|Great Britain|   1|     0|     0|    1|   2|
# |Cycling Mountain ...|        Spain|   0|     0|     1|    1|   3|
# |Cycling Mountain ...|      Denmark|   0|     0|     0|    0|   4|
# |Cycling Mountain ...|United States|   0|     0|     0|    0|   5|
# |Cycling Mountain ...|       France|   0|     0|     0|    0|   6|
# |Cycling Mountain ...|       Canada|   0|     0|     0|    0|   7|
# |Cycling Mountain ...|       Sweden|   0|     0|     0|    0|   8|
# |Cycling Mountain ...|      Namibia|   0|     0|     0|    0|   9|
# |Cycling Mountain ...|  Netherlands|   0|     0|     0|    0|  10|
# +--------------------+-------------+----+------+------+-----+----+
#
# +--------------+-------------+----+------+------+-----+----+
# |         Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +--------------+-------------+----+------+------+-----+----+
# |3x3 Basketball|       Latvia|   4|     0|     0|    4|   1|
# |3x3 Basketball|United States|   4|     0|     0|    4|   2|
# |3x3 Basketball|       Russia|   0|     8|     0|    8|   3|
# |3x3 Basketball|        China|   0|     0|     4|    4|   4|
# |3x3 Basketball|       Serbia|   0|     0|     4|    4|   5|
# |3x3 Basketball|     Mongolia|   0|     0|     0|    0|   6|
# |3x3 Basketball|       Poland|   0|     0|     0|    0|   7|
# |3x3 Basketball|        Italy|   0|     0|     0|    0|   8|
# |3x3 Basketball|        Japan|   0|     0|     0|    0|   9|
# |3x3 Basketball|  Netherlands|   0|     0|     0|    0|  10|
# +--------------+-------------+----+------+------+-----+----+
#
# +------------+-----------+----+------+------+-----+----+
# |       Sport|    Country|Gold|Silver|Bronze|Total|Rank|
# +------------+-----------+----+------+------+-----+----+
# |Cycling Road|Netherlands|   1|     2|     1|    4|   1|
# |Cycling Road|   Slovenia|   1|     0|     1|    2|   2|
# |Cycling Road|    Ecuador|   1|     0|     0|    1|   3|
# |Cycling Road|    Austria|   1|     0|     0|    1|   4|
# |Cycling Road|Switzerland|   0|     1|     0|    1|   5|
# |Cycling Road|    Belgium|   0|     1|     0|    1|   6|
# |Cycling Road|  Australia|   0|     0|     1|    1|   7|
# |Cycling Road|      Italy|   0|     0|     1|    1|   8|
# |Cycling Road|    Namibia|   0|     0|     0|    0|   9|
# |Cycling Road|     Greece|   0|     0|     0|    0|  10|
# +------------+-----------+----+------+------+-----+----+
#
# +---------+-------------+----+------+------+-----+----+
# |    Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +---------+-------------+----+------+------+-----+----+
# |Wrestling|        Japan|   5|     1|     1|    7|   1|
# |Wrestling|       Russia|   4|     0|     4|    8|   2|
# |Wrestling|United States|   3|     2|     4|    9|   3|
# |Wrestling|         Cuba|   2|     0|     1|    3|   4|
# |Wrestling|      Ukraine|   1|     1|     2|    4|   5|
# |Wrestling|         Iran|   1|     1|     2|    4|   6|
# |Wrestling|      Hungary|   1|     1|     0|    2|   7|
# |Wrestling|      Germany|   1|     0|     2|    3|   8|
# |Wrestling|        China|   0|     2|     2|    4|   9|
# |Wrestling|   Kyrgyzstan|   0|     2|     1|    3|  10|
# +---------+-------------+----+------+------+-----+----+
#
# +------------+----------------+----+------+------+-----+----+
# |       Sport|         Country|Gold|Silver|Bronze|Total|Rank|
# +------------+----------------+----+------+------+-----+----+
# |Table Tennis|           China|   8|     4|     0|   12|   1|
# |Table Tennis|           Japan|   2|     3|     4|    9|   2|
# |Table Tennis|         Germany|   0|     3|     1|    4|   3|
# |Table Tennis|Hong Kong, China|   0|     0|     3|    3|   4|
# |Table Tennis|  Chinese Taipei|   0|     0|     2|    2|   5|
# |Table Tennis|            Iran|   0|     0|     0|    0|   6|
# |Table Tennis|         Denmark|   0|     0|     0|    0|   7|
# |Table Tennis|          Greece|   0|     0|     0|    0|   8|
# |Table Tennis|         Austria|   0|     0|     0|    0|   9|
# |Table Tennis|        Bulgaria|   0|     0|     0|    0|  10|
# +------------+----------------+----+------+------+-----+----+
#
# +---------+-------------+----+------+------+-----+----+
# |    Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +---------+-------------+----+------+------+-----+----+
# |Taekwondo|       Russia|   2|     1|     1|    4|   1|
# |Taekwondo|       Serbia|   1|     0|     1|    2|   2|
# |Taekwondo|      Croatia|   1|     0|     1|    2|   3|
# |Taekwondo|   Uzbekistan|   1|     0|     0|    1|   4|
# |Taekwondo|     Thailand|   1|     0|     0|    1|   5|
# |Taekwondo|        Italy|   1|     0|     0|    1|   6|
# |Taekwondo|United States|   1|     0|     0|    1|   7|
# |Taekwondo|Great Britain|   0|     2|     1|    3|   8|
# |Taekwondo|  South Korea|   0|     1|     2|    3|   9|
# |Taekwondo|      Tunisia|   0|     1|     0|    1|  10|
# +---------+-------------+----+------+------+-----+----+
#
# +----------+-------------+----+------+------+-----+----+
# |     Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +----------+-------------+----+------+------+-----+----+
# |Water Polo|       Serbia|  13|     0|     0|   13|   1|
# |Water Polo|United States|  13|     0|     0|   13|   2|
# |Water Polo|       Greece|   0|    13|     0|   13|   3|
# |Water Polo|        Spain|   0|    13|     0|   13|   4|
# |Water Polo|      Hungary|   0|     0|    26|   26|   5|
# |Water Polo|       Russia|   0|     0|     0|    0|   6|
# |Water Polo|        Japan|   0|     0|     0|    0|   7|
# |Water Polo|   Montenegro|   0|     0|     0|    0|   8|
# |Water Polo| South Africa|   0|     0|     0|    0|   9|
# |Water Polo|      Croatia|   0|     0|     0|    0|  10|
# +----------+-------------+----+------+------+-----+----+
#
# +-------------+--------------+----+------+------+-----+----+
# |        Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +-------------+--------------+----+------+------+-----+----+
# |Weightlifting|         China|   7|     1|     0|    8|   1|
# |Weightlifting|       Ecuador|   1|     1|     0|    2|   2|
# |Weightlifting|Chinese Taipei|   1|     0|     1|    2|   3|
# |Weightlifting|       Georgia|   1|     0|     1|    2|   4|
# |Weightlifting|   Philippines|   1|     0|     0|    1|   5|
# |Weightlifting|        Canada|   1|     0|     0|    1|   6|
# |Weightlifting|         Qatar|   1|     0|     0|    1|   7|
# |Weightlifting|    Uzbekistan|   1|     0|     0|    1|   8|
# |Weightlifting|     Venezuela|   0|     2|     0|    2|   9|
# |Weightlifting|     Indonesia|   0|     1|     2|    3|  10|
# +-------------+--------------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |  Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |Surfing|       Brazil|   1|     0|     0|    1|   1|
# |Surfing|United States|   1|     0|     0|    1|   2|
# |Surfing|        Japan|   0|     1|     1|    2|   3|
# |Surfing| South Africa|   0|     1|     0|    1|   4|
# |Surfing|    Australia|   0|     0|     1|    1|   5|
# |Surfing|    Indonesia|   0|     0|     0|    0|   6|
# |Surfing|     Portugal|   0|     0|     0|    0|   7|
# |Surfing|    Argentina|   0|     0|     0|    0|   8|
# |Surfing|         Peru|   0|     0|     0|    0|   9|
# |Surfing|   Costa Rica|   0|     0|     0|    0|  10|
# +-------+-------------+----+------+------+-----+----+
#
# +--------------+-------------+----+------+------+-----+----+
# |         Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +--------------+-------------+----+------+------+-----+----+
# |Sport Climbing|     Slovenia|   1|     0|     0|    1|   1|
# |Sport Climbing|        Spain|   1|     0|     0|    1|   2|
# |Sport Climbing|        Japan|   0|     1|     1|    2|   3|
# |Sport Climbing|United States|   0|     1|     0|    1|   4|
# |Sport Climbing|      Austria|   0|     0|     1|    1|   5|
# |Sport Climbing|Great Britain|   0|     0|     0|    0|   6|
# |Sport Climbing|       Poland|   0|     0|     0|    0|   7|
# |Sport Climbing|      Germany|   0|     0|     0|    0|   8|
# |Sport Climbing|   Kazakhstan|   0|     0|     0|    0|   9|
# |Sport Climbing|    Australia|   0|     0|     0|    0|  10|
# +--------------+-------------+----+------+------+-----+----+
#
# +------------------+-------------+----+------+------+-----+----+
# |             Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +------------------+-------------+----+------+------+-----+----+
# |Cycling BMX Racing|Great Britain|   1|     1|     0|    2|   1|
# |Cycling BMX Racing|  Netherlands|   1|     0|     1|    2|   2|
# |Cycling BMX Racing|     Colombia|   0|     1|     1|    2|   3|
# |Cycling BMX Racing|       Norway|   0|     0|     0|    0|   4|
# |Cycling BMX Racing|  Switzerland|   0|     0|     0|    0|   5|
# |Cycling BMX Racing|       Russia|   0|     0|     0|    0|   6|
# |Cycling BMX Racing|       Latvia|   0|     0|     0|    0|   7|
# |Cycling BMX Racing|      Ecuador|   0|     0|     0|    0|   8|
# |Cycling BMX Racing|      Denmark|   0|     0|     0|    0|   9|
# |Cycling BMX Racing|  New Zealand|   0|     0|     0|    0|  10|
# +------------------+-------------+----+------+------+-----+----+
#
# +--------------------+-------------+----+------+------+-----+----+
# |               Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +--------------------+-------------+----+------+------+-----+----+
# |Trampoline Gymnas...|        China|   1|     2|     0|    3|   1|
# |Trampoline Gymnas...|      Belarus|   1|     0|     0|    1|   2|
# |Trampoline Gymnas...|  New Zealand|   0|     0|     1|    1|   3|
# |Trampoline Gymnas...|Great Britain|   0|     0|     1|    1|   4|
# |Trampoline Gymnas...|       Canada|   0|     0|     0|    0|   5|
# |Trampoline Gymnas...|     Colombia|   0|     0|     0|    0|   6|
# |Trampoline Gymnas...|       France|   0|     0|     0|    0|   7|
# |Trampoline Gymnas...|    Australia|   0|     0|     0|    0|   8|
# |Trampoline Gymnas...|      Ukraine|   0|     0|     0|    0|   9|
# |Trampoline Gymnas...|        Japan|   0|     0|     0|    0|  10|
# +--------------------+-------------+----+------+------+-----+----+
#
# +-----------------+-------------+----+------+------+-----+----+
# |            Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +-----------------+-------------+----+------+------+-----+----+
# |Modern Pentathlon|Great Britain|   2|     0|     0|    2|   1|
# |Modern Pentathlon|        Egypt|   0|     1|     0|    1|   2|
# |Modern Pentathlon|    Lithuania|   0|     1|     0|    1|   3|
# |Modern Pentathlon|      Hungary|   0|     0|     1|    1|   4|
# |Modern Pentathlon|  South Korea|   0|     0|     1|    1|   5|
# |Modern Pentathlon|       Mexico|   0|     0|     0|    0|   6|
# |Modern Pentathlon|   Uzbekistan|   0|     0|     0|    0|   7|
# |Modern Pentathlon|    Australia|   0|     0|     0|    0|   8|
# |Modern Pentathlon|      Belarus|   0|     0|     0|    0|   9|
# |Modern Pentathlon|    Guatemala|   0|     0|     0|    0|  10|
# +-----------------+-------------+----+------+------+-----+----+
#
# +----------+------------------+----+------+------+-----+----+
# |     Sport|           Country|Gold|Silver|Bronze|Total|Rank|
# +----------+------------------+----+------+------+-----+----+
# |Volleyball|            France|  12|     0|     0|   12|   1|
# |Volleyball|     United States|  12|     0|     0|   12|   2|
# |Volleyball|            Brazil|   0|    12|     0|   12|   3|
# |Volleyball|            Russia|   0|    12|     0|   12|   4|
# |Volleyball|            Serbia|   0|     0|    12|   12|   5|
# |Volleyball|         Argentina|   0|     0|    12|   12|   6|
# |Volleyball|             China|   0|     0|     0|    0|   7|
# |Volleyball|Dominican Republic|   0|     0|     0|    0|   8|
# |Volleyball|             Japan|   0|     0|     0|    0|   9|
# |Volleyball|             Italy|   0|     0|     0|    0|  10|
# +----------+------------------+----+------+------+-----+----+
#
# +-------+--------------+----+------+------+-----+----+
# |  Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +-------+--------------+----+------+------+-----+----+
# |Archery|   South Korea|   9|     0|     0|    9|   1|
# |Archery|        Turkey|   1|     0|     0|    1|   2|
# |Archery|        Russia|   0|     4|     0|    4|   3|
# |Archery|Chinese Taipei|   0|     3|     0|    3|   4|
# |Archery|   Netherlands|   0|     2|     0|    2|   5|
# |Archery|         Italy|   0|     1|     1|    2|   6|
# |Archery|         Japan|   0|     0|     4|    4|   7|
# |Archery|       Germany|   0|     0|     3|    3|   8|
# |Archery|        Mexico|   0|     0|     2|    2|   9|
# |Archery|       Ukraine|   0|     0|     0|    0|  10|
# +-------+--------------+----+------+------+-----+----+
#
# +-----------------+-------------+----+------+------+-----+----+
# |            Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +-----------------+-------------+----+------+------+-----+----+
# |Artistic Swimming|       Russia|  10|     0|     0|   10|   1|
# |Artistic Swimming|        China|   0|    10|     0|   10|   2|
# |Artistic Swimming|      Ukraine|   0|     0|    10|   10|   3|
# |Artistic Swimming|      Belarus|   0|     0|     0|    0|   4|
# |Artistic Swimming|United States|   0|     0|     0|    0|   5|
# |Artistic Swimming|        Japan|   0|     0|     0|    0|   6|
# |Artistic Swimming|     Colombia|   0|     0|     0|    0|   7|
# |Artistic Swimming|  Netherlands|   0|     0|     0|    0|   8|
# |Artistic Swimming|       Canada|   0|     0|     0|    0|   9|
# |Artistic Swimming|   Kazakhstan|   0|     0|     0|    0|  10|
# +-----------------+-------------+----+------+------+-----+----+
#
# +-------+----------------+----+------+------+-----+----+
# |  Sport|         Country|Gold|Silver|Bronze|Total|Rank|
# +-------+----------------+----+------+------+-----+----+
# |Fencing|          Russia|   9|    10|     1|   20|   1|
# |Fencing|          France|   5|     8|     1|   14|   2|
# |Fencing|     South Korea|   4|     4|     9|   17|   3|
# |Fencing|         Estonia|   4|     0|     1|    5|   4|
# |Fencing|           Japan|   4|     0|     0|    4|   5|
# |Fencing|         Hungary|   1|     1|     4|    6|   6|
# |Fencing|   United States|   1|     0|     4|    5|   7|
# |Fencing|           China|   1|     0|     0|    1|   8|
# |Fencing|Hong Kong, China|   1|     0|     0|    1|   9|
# |Fencing|           Italy|   0|     6|     8|   14|  10|
# +-------+----------------+----+------+------+-----+----+
#
# +------+-------------+----+------+------+-----+----+
# | Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +------+-------------+----+------+------+-----+----+
# |Hockey|      Belgium|  18|     0|     0|   18|   1|
# |Hockey|  Netherlands|  18|     0|     0|   18|   2|
# |Hockey|    Argentina|   0|    18|     0|   18|   3|
# |Hockey|    Australia|   0|    18|     0|   18|   4|
# |Hockey|Great Britain|   0|     0|    18|   18|   5|
# |Hockey|        India|   0|     0|    18|   18|   6|
# |Hockey|        Japan|   0|     0|     0|    0|   7|
# |Hockey| South Africa|   0|     0|     0|    0|   8|
# |Hockey|      Ireland|   0|     0|     0|    0|   9|
# |Hockey|       Canada|   0|     0|     0|    0|  10|
# +------+-------------+----+------+------+-----+----+
#
# +--------+-------------+----+------+------+-----+----+
# |   Sport|      Country|Gold|Silver|Bronze|Total|Rank|
# +--------+-------------+----+------+------+-----+----+
# |Football|       Brazil|  22|     0|     0|   22|   1|
# |Football|       Canada|  22|     0|     0|   22|   2|
# |Football|       Sweden|   0|    22|     0|   22|   3|
# |Football|        Spain|   0|    22|     0|   22|   4|
# |Football|United States|   0|     0|    22|   22|   5|
# |Football|       Mexico|   0|     0|    22|   22|   6|
# |Football|     Honduras|   0|     0|     0|    0|   7|
# |Football|  New Zealand|   0|     0|     0|    0|   8|
# |Football|        Chile|   0|     0|     0|    0|   9|
# |Football|  South Korea|   0|     0|     0|    0|  10|
# +--------+-------------+----+------+------+-----+----+

# %% [markdown]
# # 3. DataFrames for each country showing medal counts in each sports they won

# %%
# Get the unique list of countries from the DataFrame
unique_countries = [row['Country'] for row in df.select('Country').distinct().collect()]

# Create an empty dictionary to store DataFrames for each country
country_dataframes = {}

# Iterate through each country
for country in unique_countries:
    # Filter the DataFrame for the current country
    country_df = df.filter(df["Country"] == country)

    # Group the filtered DataFrame by "Country" and "Sport" and calculate medal counts
    result_df = country_df.groupBy("Country", "Sport").agg(
        count(when(country_df["Medal"] == "Gold", True)).alias("Gold"),
        count(when(country_df["Medal"] == "Silver", True)).alias("Silver"),
        count(when(country_df["Medal"] == "Bronze", True)).alias("Bronze"),
        count(when(country_df['Medal'] != 'None', True)).alias('Total')
    )

    # Skip countries with zero total medals
    total_medals = result_df.groupBy("Country").agg(F.sum("Total").alias("Total"))
    if total_medals.filter(col("Total") > 0).count() > 0:
        # Filter out sports with zero medals
        result_df = result_df.filter(col('Total') > 0)

        # Define a Window specification for ranking within the country
        window_spec = Window.partitionBy("Country").orderBy(
            col("Gold").desc(), col("Silver").desc(), col("Bronze").desc(), col("Total").desc()
        )

        # Add a "Rank" column based on medal counts within the country
        result_df = result_df.withColumn("Rank", F.row_number().over(window_spec))
        result_df.show()
        # Store the result DataFrame in the dictionary using the country name as the key
        country_dataframes[country] = result_df

# For example, to access the top sports for "Colombia," use country_dataframes["Colombia"].show()
# Out:
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# | Russia|  Artistic Swimming|  10|     0|     0|   10|   1|
# | Russia|            Fencing|   9|    10|     1|   20|   2|
# | Russia|Artistic Gymnastics|   8|     2|     4|   14|   3|
# | Russia|          Wrestling|   4|     0|     4|    8|   4|
# | Russia|           Swimming|   2|     7|     1|   10|   5|
# | Russia|           Shooting|   2|     5|     3|   10|   6|
# | Russia|             Tennis|   2|     3|     0|    5|   7|
# | Russia|          Taekwondo|   2|     1|     1|    4|   8|
# | Russia|             Boxing|   1|     1|     4|    6|   9|
# | Russia|          Athletics|   1|     1|     0|    2|  10|
# | Russia|           Handball|   0|    15|     0|   15|  11|
# | Russia|         Volleyball|   0|    12|     0|   12|  12|
# | Russia|     3x3 Basketball|   0|     8|     0|    8|  13|
# | Russia|Rhythmic Gymnastics|   0|     6|     0|    6|  14|
# | Russia|            Archery|   0|     4|     0|    4|  15|
# | Russia|             Rowing|   0|     3|     0|    3|  16|
# | Russia|   Beach Volleyball|   0|     2|     0|    2|  17|
# | Russia|      Cycling Track|   0|     0|     5|    5|  18|
# | Russia|               Judo|   0|     0|     3|    3|  19|
# | Russia|             Diving|   0|     0|     2|    2|  20|
# +-------+-------------------+----+------+------+-----+----+
#
# +--------------+-------------------+----+------+------+-----+----+
# |       Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +--------------+-------------------+----+------+------+-----+----+
# |Chinese Taipei|          Badminton|   2|     1|     0|    3|   1|
# |Chinese Taipei|      Weightlifting|   1|     0|     1|    2|   2|
# |Chinese Taipei|            Archery|   0|     3|     0|    3|   3|
# |Chinese Taipei|Artistic Gymnastics|   0|     1|     0|    1|   4|
# |Chinese Taipei|               Judo|   0|     1|     0|    1|   5|
# |Chinese Taipei|       Table Tennis|   0|     0|     2|    2|   6|
# |Chinese Taipei|               Golf|   0|     0|     1|    1|   7|
# |Chinese Taipei|             Boxing|   0|     0|     1|    1|   8|
# |Chinese Taipei|          Taekwondo|   0|     0|     1|    1|   9|
# |Chinese Taipei|             Karate|   0|     0|     1|    1|  10|
# +--------------+-------------------+----+------+------+-----+----+
#
# +-------+----------+----+------+------+-----+----+
# |Country|     Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+----------+----+------+------+-----+----+
# | Sweden|Equestrian|   4|     1|     0|    5|   1|
# | Sweden| Athletics|   2|     1|     0|    3|   2|
# | Sweden|  Football|   0|    22|     0|   22|   3|
# | Sweden|   Sailing|   0|     3|     0|    3|   4|
# | Sweden|  Swimming|   0|     1|     0|    1|   5|
# +-------+----------+----+------+------+-----+----+
#
# +-----------+-------------+----+------+------+-----+----+
# |    Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-----------+-------------+----+------+------+-----+----+
# |Philippines|Weightlifting|   1|     0|     0|    1|   1|
# |Philippines|       Boxing|   0|     2|     1|    3|   2|
# +-----------+-------------+----+------+------+-----+----+
#
# +--------+-------------+----+------+------+-----+----+
# | Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+-------------+----+------+------+-----+----+
# |Malaysia|Cycling Track|   0|     1|     0|    1|   1|
# |Malaysia|    Badminton|   0|     0|     2|    2|   2|
# +--------+-------------+----+------+------+-----+----+
#
# +-------+------------+----+------+------+-----+----+
# |Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+------------+----+------+------+-----+----+
# |   Fiji|Rugby Sevens|  13|     0|    13|   26|   1|
# +-------+------------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# | Turkey|             Boxing|   1|     1|     0|    2|   1|
# | Turkey|            Archery|   1|     0|     0|    1|   2|
# | Turkey|             Karate|   0|     1|     3|    4|   3|
# | Turkey|          Wrestling|   0|     0|     3|    3|   4|
# | Turkey|          Taekwondo|   0|     0|     2|    2|   5|
# | Turkey|Artistic Gymnastics|   0|     0|     1|    1|   6|
# +-------+-------------------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# |Germany|      Cycling Track|   6|     3|     0|    9|   1|
# |Germany|         Equestrian|   6|     1|     0|    7|   2|
# |Germany|       Canoe Sprint|   4|     2|     2|    8|   3|
# |Germany|          Athletics|   1|     2|     0|    3|   4|
# |Germany|       Canoe Slalom|   1|     0|     3|    4|   5|
# |Germany|          Wrestling|   1|     0|     2|    3|   6|
# |Germany|             Tennis|   1|     0|     0|    1|   7|
# |Germany|  Marathon Swimming|   1|     0|     0|    1|   8|
# |Germany|             Rowing|   0|    11|     0|   11|   9|
# |Germany|       Table Tennis|   0|     3|     1|    4|  10|
# |Germany|            Sailing|   0|     2|     4|    6|  11|
# |Germany|               Judo|   0|     1|    13|   14|  12|
# |Germany|Artistic Gymnastics|   0|     1|     0|    1|  13|
# |Germany|             Diving|   0|     0|     4|    4|  14|
# |Germany|            Archery|   0|     0|     3|    3|  15|
# |Germany|           Swimming|   0|     0|     2|    2|  16|
# +-------+-------------------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# | Jordan|Taekwondo|   0|     1|     0|    1|   1|
# | Jordan|   Karate|   0|     0|     1|    1|   2|
# +-------+---------+----+------+------+-----+----+
#
# +-----------+---------+----+------+------+-----+----+
# |    Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-----------+---------+----+------+------+-----+----+
# |Ivory Coast|Taekwondo|   0|     0|     1|    1|   1|
# +-----------+---------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# | France|     Handball|  32|     0|     0|   32|   1|
# | France|         Judo|  12|     3|     3|   18|   2|
# | France|   Volleyball|  12|     0|     0|   12|   3|
# | France|      Fencing|   5|     8|     1|   14|   4|
# | France|       Rowing|   2|     2|     0|    4|   5|
# | France|     Shooting|   1|     0|     0|    1|   6|
# | France|       Karate|   1|     0|     0|    1|   7|
# | France| Rugby Sevens|   0|    13|     0|   13|   8|
# | France|   Basketball|   0|    12|    12|   24|   9|
# | France|      Sailing|   0|     2|     2|    4|  10|
# | France|    Athletics|   0|     1|     0|    1|  11|
# | France|     Swimming|   0|     1|     0|    1|  12|
# | France|Cycling Track|   0|     0|     7|    7|  13|
# | France|    Triathlon|   0|     0|     5|    5|  14|
# | France|   Equestrian|   0|     0|     3|    3|  15|
# | France|    Taekwondo|   0|     0|     1|    1|  16|
# +-------+-------------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# | Greece|          Athletics|   1|     0|     0|    1|   1|
# | Greece|             Rowing|   1|     0|     0|    1|   2|
# | Greece|         Water Polo|   0|    13|     0|   13|   3|
# | Greece|Artistic Gymnastics|   0|     0|     1|    1|   4|
# +-------+-------------------+----+------+------+-----+----+
#
# +-------+-----+----+------+------+-----+----+
# |Country|Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-----+----+------+------+-----+----+
# | Kosovo| Judo|   2|     0|     0|    2|   1|
# +-------+-----+----+------+------+-----+----+
#
# +--------+------------+----+------+------+-----+----+
# | Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+------------+----+------+------+-----+----+
# |Slovakia|    Shooting|   1|     0|     0|    1|   1|
# |Slovakia|Canoe Slalom|   0|     1|     0|    1|   2|
# |Slovakia|        Golf|   0|     1|     0|    1|   3|
# |Slovakia|Canoe Sprint|   0|     0|     4|    4|   4|
# +--------+------------+----+------+------+-----+----+
#
# +----------------+-------------+----+------+------+-----+----+
# |         Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +----------------+-------------+----+------+------+-----+----+
# |Hong Kong, China|      Fencing|   1|     0|     0|    1|   1|
# |Hong Kong, China|     Swimming|   0|     2|     0|    2|   2|
# |Hong Kong, China| Table Tennis|   0|     0|     3|    3|   3|
# |Hong Kong, China|Cycling Track|   0|     0|     1|    1|   4|
# |Hong Kong, China|       Karate|   0|     0|     1|    1|   5|
# +----------------+-------------+----+------+------+-----+----+
#
# +---------+------------+----+------+------+-----+----+
# |  Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +---------+------------+----+------+------+-----+----+
# |Argentina|      Hockey|   0|    18|     0|   18|   1|
# |Argentina|Rugby Sevens|   0|     0|    13|   13|   2|
# |Argentina|  Volleyball|   0|     0|    12|   12|   3|
# +---------+------------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# |Belgium|             Hockey|  18|     0|     0|   18|   1|
# |Belgium|          Athletics|   1|     0|     1|    2|   2|
# |Belgium|Artistic Gymnastics|   1|     0|     0|    1|   3|
# |Belgium|       Cycling Road|   0|     1|     0|    1|   4|
# |Belgium|         Equestrian|   0|     0|     4|    4|   5|
# |Belgium|               Judo|   0|     0|     1|    1|   6|
# +-------+-------------------+----+------+------+-----+----+
#
# +-------------+--------------------+----+------+------+-----+----+
# |      Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +-------------+--------------------+----+------+------+-----+----+
# |Great Britain|            Swimming|  12|     7|     1|   20|   1|
# |Great Britain|             Sailing|   5|     2|     1|    8|   2|
# |Great Britain|           Triathlon|   5|     2|     0|    7|   3|
# |Great Britain|          Equestrian|   5|     1|     5|   11|   4|
# |Great Britain|       Cycling Track|   4|    12|     1|   17|   5|
# |Great Britain|              Boxing|   2|     2|     2|    6|   6|
# |Great Britain|              Diving|   2|     0|     2|    4|   7|
# |Great Britain|   Modern Pentathlon|   2|     0|     0|    2|   8|
# |Great Britain|  Cycling BMX Racing|   1|     1|     0|    2|   9|
# |Great Britain| Artistic Gymnastics|   1|     0|     4|    5|  10|
# |Great Britain|Cycling BMX Frees...|   1|     0|     1|    2|  11|
# |Great Britain|Cycling Mountain ...|   1|     0|     0|    1|  12|
# |Great Britain|           Athletics|   0|     8|     7|   15|  13|
# |Great Britain|              Rowing|   0|     4|     9|   13|  14|
# |Great Britain|           Taekwondo|   0|     2|     1|    3|  15|
# |Great Britain|        Canoe Slalom|   0|     1|     0|    1|  16|
# |Great Britain|       Weightlifting|   0|     1|     0|    1|  17|
# |Great Britain|              Hockey|   0|     0|    18|   18|  18|
# |Great Britain|       Skateboarding|   0|     0|     1|    1|  19|
# |Great Britain|                Judo|   0|     0|     1|    1|  20|
# +-------------+--------------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +----------+---------+----+------+------+-----+----+
# |   Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +----------+---------+----+------+------+-----+----+
# |San Marino| Shooting|   0|     2|     1|    3|   1|
# |San Marino|Wrestling|   0|     0|     1|    1|   2|
# +----------+---------+----+------+------+-----+----+
#
# +-------+----------------+----+------+------+-----+----+
# |Country|           Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+----------------+----+------+------+-----+----+
# |  Qatar|       Athletics|   1|     0|     0|    1|   1|
# |  Qatar|   Weightlifting|   1|     0|     0|    1|   2|
# |  Qatar|Beach Volleyball|   0|     0|     2|    2|   3|
# +-------+----------------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |Ecuador|Weightlifting|   1|     1|     0|    2|   1|
# |Ecuador| Cycling Road|   1|     0|     0|    1|   2|
# +-------+-------------+----+------+------+-----+----+
#
# +-------+--------+----+------+------+-----+----+
# |Country|   Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------+----+------+------+-----+----+
# |Finland|  Boxing|   0|     0|     1|    1|   1|
# |Finland|Swimming|   0|     0|     1|    1|   2|
# +-------+--------+----+------+------+-----+----+
#
# +-------+------+----+------+------+-----+----+
# |Country| Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+------+----+------+------+-----+----+
# |  Ghana|Boxing|   0|     0|     1|    1|   1|
# +-------+------+----+------+------+-----+----+
#
# +-------------+-------------------+----+------+------+-----+----+
# |      Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------------+-------------------+----+------+------+-----+----+
# |United States|         Basketball|  24|     0|     0|   24|   1|
# |United States|           Swimming|  22|    22|    15|   59|   2|
# |United States|          Athletics|  21|    17|    14|   52|   3|
# |United States|         Water Polo|  13|     0|     0|   13|   4|
# |United States|         Volleyball|  12|     0|     0|   12|   5|
# |United States|     3x3 Basketball|   4|     0|     0|    4|   6|
# |United States|           Shooting|   3|     3|     2|    8|   7|
# |United States|          Wrestling|   3|     2|     4|    9|   8|
# |United States|Artistic Gymnastics|   2|     5|     2|    9|   9|
# |United States|               Golf|   2|     0|     0|    2|  10|
# |United States|   Beach Volleyball|   2|     0|     0|    2|  11|
# |United States|      Cycling Track|   1|     0|     5|    6|  12|
# |United States|            Fencing|   1|     0|     4|    5|  13|
# |United States|       Canoe Sprint|   1|     0|     0|    1|  14|
# |United States|          Taekwondo|   1|     0|     0|    1|  15|
# |United States|            Surfing|   1|     0|     0|    1|  16|
# |United States|  Baseball/Softball|   0|    39|     0|   39|  17|
# |United States|         Equestrian|   0|     7|     0|    7|  18|
# |United States|          Triathlon|   0|     5|     1|    6|  19|
# |United States|             Diving|   0|     4|     1|    5|  20|
# +-------------+-------------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |  India|    Athletics|   1|     0|     0|    1|   1|
# |  India|    Wrestling|   0|     1|     1|    2|   2|
# |  India|Weightlifting|   0|     1|     0|    1|   3|
# |  India|       Hockey|   0|     0|    18|   18|   4|
# |  India|    Badminton|   0|     0|     1|    1|   5|
# |  India|       Boxing|   0|     0|     1|    1|   6|
# +-------+-------------+----+------+------+-----+----+
#
# +-------+--------------------+----+------+------+-----+----+
# |Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------------------+----+------+------+-----+----+
# |  China|              Diving|  10|     6|     0|   16|   1|
# |  China|            Swimming|   8|     5|     1|   14|   2|
# |  China|        Table Tennis|   8|     4|     0|   12|   3|
# |  China|       Weightlifting|   7|     1|     0|    8|   4|
# |  China|            Shooting|   6|     1|     6|   13|   5|
# |  China|              Rowing|   4|     0|    11|   15|   6|
# |  China|           Badminton|   3|     7|     0|   10|   7|
# |  China| Artistic Gymnastics|   3|     3|     5|   11|   8|
# |  China|       Cycling Track|   3|     0|     0|    3|   9|
# |  China|        Canoe Sprint|   2|     3|     0|    5|  10|
# |  China|           Athletics|   2|     2|     1|    5|  11|
# |  China|Trampoline Gymnas...|   1|     2|     0|    3|  12|
# |  China|             Sailing|   1|     0|     1|    2|  13|
# |  China|             Fencing|   1|     0|     0|    1|  14|
# |  China|   Artistic Swimming|   0|    10|     0|   10|  15|
# |  China|           Wrestling|   0|     2|     2|    4|  16|
# |  China|              Boxing|   0|     2|     0|    2|  17|
# |  China|              Karate|   0|     1|     1|    2|  18|
# |  China|      3x3 Basketball|   0|     0|     4|    4|  19|
# |  China|           Taekwondo|   0|     0|     1|    1|  20|
# +-------+--------------------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Bahamas|Athletics|   2|     0|     0|    2|   1|
# +-------+---------+----+------+------+-----+----+
#
# +-------+--------------------+----+------+------+-----+----+
# |Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------------------+----+------+------+-----+----+
# |Belarus|Trampoline Gymnas...|   1|     0|     0|    1|   1|
# |Belarus|        Canoe Sprint|   0|     4|     0|    4|   2|
# |Belarus|           Wrestling|   0|     2|     1|    3|   3|
# |Belarus|           Athletics|   0|     0|     1|    1|   4|
# |Belarus| Rhythmic Gymnastics|   0|     0|     1|    1|   5|
# +-------+--------------------+----+------+------+-----+----+
#
# +-------+--------+----+------+------+-----+----+
# |Country|   Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------+----+------+------+-----+----+
# | Kuwait|Shooting|   0|     0|     1|    1|   1|
# +-------+--------+----+------+------+-----+----+
#
# +-----------+---------+----+------+------+-----+----+
# |    Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-----------+---------+----+------+------+-----+----+
# |Puerto Rico|Athletics|   1|     0|     0|    1|   1|
# +-----------+---------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# |Croatia|             Tennis|   2|     2|     0|    4|   1|
# |Croatia|             Rowing|   2|     0|     1|    3|   2|
# |Croatia|          Taekwondo|   1|     0|     1|    2|   3|
# |Croatia|            Sailing|   0|     1|     0|    1|   4|
# |Croatia|Artistic Gymnastics|   0|     1|     0|    1|   5|
# +-------+-------------------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Nigeria|Wrestling|   0|     1|     0|    1|   1|
# |Nigeria|Athletics|   0|     0|     1|    1|   2|
# +-------+---------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# |  Italy|          Athletics|  10|     0|     0|   10|   1|
# |  Italy|      Cycling Track|   6|     0|     1|    7|   2|
# |  Italy|             Rowing|   2|     0|     6|    8|   3|
# |  Italy|            Sailing|   2|     0|     0|    2|   4|
# |  Italy|             Karate|   1|     0|     1|    2|   5|
# |  Italy|          Taekwondo|   1|     0|     0|    1|   6|
# |  Italy|            Fencing|   0|     6|     8|   14|   7|
# |  Italy|           Swimming|   0|     6|     7|   13|   8|
# |  Italy|      Weightlifting|   0|     1|     2|    3|   9|
# |  Italy|            Archery|   0|     1|     1|    2|  10|
# |  Italy|           Shooting|   0|     1|     0|    1|  11|
# |  Italy|       Canoe Sprint|   0|     1|     0|    1|  12|
# |  Italy|Artistic Gymnastics|   0|     1|     0|    1|  13|
# |  Italy|Rhythmic Gymnastics|   0|     0|     5|    5|  14|
# |  Italy|               Judo|   0|     0|     2|    2|  15|
# |  Italy|             Boxing|   0|     0|     1|    1|  16|
# |  Italy|       Cycling Road|   0|     0|     1|    1|  17|
# |  Italy|          Wrestling|   0|     0|     1|    1|  18|
# |  Italy|  Marathon Swimming|   0|     0|     1|    1|  19|
# +-------+-------------------+----+------+------+-----+----+
#
# +---------+-----------------+----+------+------+-----+----+
# |  Country|            Sport|Gold|Silver|Bronze|Total|Rank|
# +---------+-----------------+----+------+------+-----+----+
# |Lithuania|Modern Pentathlon|   0|     1|     0|    1|   1|
# +---------+-----------------+----+------+------+-----+----+
#
# +-------+----------------+----+------+------+-----+----+
# |Country|           Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+----------------+----+------+------+-----+----+
# | Norway|       Athletics|   2|     1|     0|    3|   1|
# | Norway|Beach Volleyball|   2|     0|     0|    2|   2|
# | Norway|       Triathlon|   1|     0|     0|    1|   3|
# | Norway|          Rowing|   0|     1|     0|    1|   4|
# | Norway|        Handball|   0|     0|    15|   15|   5|
# | Norway|         Sailing|   0|     0|     1|    1|   6|
# +-------+----------------+----+------+------+-----+----+
#
# +------------+-------------+----+------+------+-----+----+
# |     Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +------------+-------------+----+------+------+-----+----+
# |Turkmenistan|Weightlifting|   0|     1|     0|    1|   1|
# +------------+-------------+----+------+------+-----+----+
#
# +-------+--------------------+----+------+------+-----+----+
# |Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------------------+----+------+------+-----+----+
# |  Spain|            Shooting|   2|     0|     0|    2|   1|
# |  Spain|              Karate|   1|     1|     0|    2|   2|
# |  Spain|      Sport Climbing|   1|     0|     0|    1|   3|
# |  Spain|            Football|   0|    22|     0|   22|   4|
# |  Spain|          Water Polo|   0|    13|     0|   13|   5|
# |  Spain|        Canoe Sprint|   0|     5|     0|    5|   6|
# |  Spain|        Canoe Slalom|   0|     1|     0|    1|   7|
# |  Spain|           Taekwondo|   0|     1|     0|    1|   8|
# |  Spain| Artistic Gymnastics|   0|     1|     0|    1|   9|
# |  Spain|            Handball|   0|     0|    16|   16|  10|
# |  Spain|             Sailing|   0|     0|     3|    3|  11|
# |  Spain|           Athletics|   0|     0|     1|    1|  12|
# |  Spain|Cycling Mountain ...|   0|     0|     1|    1|  13|
# |  Spain|              Tennis|   0|     0|     1|    1|  14|
# +-------+--------------------+----+------+------+-----+----+
#
# +-------+------------+----+------+------+-----+----+
# |Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+------------+----+------+------+-----+----+
# |   Cuba|      Boxing|   4|     0|     1|    5|   1|
# |   Cuba|   Wrestling|   2|     0|     1|    3|   2|
# |   Cuba|Canoe Sprint|   2|     0|     0|    2|   3|
# |   Cuba|   Athletics|   0|     1|     2|    3|   4|
# |   Cuba|        Judo|   0|     1|     0|    1|   5|
# |   Cuba|    Shooting|   0|     1|     0|    1|   6|
# |   Cuba|   Taekwondo|   0|     0|     1|    1|   7|
# +-------+------------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |Denmark|Cycling Track|   2|     8|     0|   10|   1|
# |Denmark|      Sailing|   1|     0|     0|    1|   2|
# |Denmark|    Badminton|   1|     0|     0|    1|   3|
# |Denmark|     Handball|   0|    15|     0|   15|   4|
# |Denmark|     Shooting|   0|     1|     0|    1|   5|
# |Denmark|       Rowing|   0|     0|     2|    2|   6|
# |Denmark| Canoe Sprint|   0|     0|     2|    2|   7|
# |Denmark|     Swimming|   0|     0|     1|    1|   8|
# +-------+-------------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |   Iran|    Wrestling|   1|     1|     2|    4|   1|
# |   Iran|     Shooting|   1|     0|     0|    1|   2|
# |   Iran|       Karate|   1|     0|     0|    1|   3|
# |   Iran|Weightlifting|   0|     1|     0|    1|   4|
# +-------+-------------+----+------+------+-----+----+
#
# +-------+------+----+------+------+-----+----+
# |Country| Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+------+----+------+------+-----+----+
# |Ireland|Rowing|   2|     0|     4|    6|   1|
# |Ireland|Boxing|   1|     0|     1|    2|   2|
# +-------+------+----+------+------+-----+----+
#
# +--------+---------+----+------+------+-----+----+
# | Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+---------+----+------+------+-----+----+
# |Thailand|Taekwondo|   1|     0|     0|    1|   1|
# |Thailand|   Boxing|   0|     0|     1|    1|   2|
# +--------+---------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Morocco|Athletics|   1|     0|     0|    1|   1|
# +-------+---------+----+------+------+-----+----+
#
# +-------+-----------------+----+------+------+-----+----+
# |Country|            Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-----------------+----+------+------+-----+----+
# |Ukraine|        Wrestling|   1|     1|     2|    4|   1|
# |Ukraine|     Canoe Sprint|   0|     2|     1|    3|   2|
# |Ukraine|           Karate|   0|     1|     1|    2|   3|
# |Ukraine|         Swimming|   0|     1|     1|    2|   4|
# |Ukraine|           Boxing|   0|     1|     0|    1|   5|
# |Ukraine|    Cycling Track|   0|     1|     0|    1|   6|
# |Ukraine|Artistic Swimming|   0|     0|    10|   10|   7|
# |Ukraine|         Shooting|   0|     0|     2|    2|   8|
# |Ukraine|        Athletics|   0|     0|     1|    1|   9|
# |Ukraine|           Tennis|   0|     0|     1|    1|  10|
# |Ukraine|             Judo|   0|     0|     1|    1|  11|
# |Ukraine|          Fencing|   0|     0|     1|    1|  12|
# +-------+-----------------+----+------+------+-----+----+
#
# +---------+--------------------+----+------+------+-----+----+
# |  Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +---------+--------------------+----+------+------+-----+----+
# |Venezuela|           Athletics|   1|     0|     0|    1|   1|
# |Venezuela|       Weightlifting|   0|     2|     0|    2|   2|
# |Venezuela|Cycling BMX Frees...|   0|     1|     0|    1|   3|
# +---------+--------------------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# | Israel|Artistic Gymnastics|   1|     0|     0|    1|   1|
# | Israel|Rhythmic Gymnastics|   1|     0|     0|    1|   2|
# | Israel|               Judo|   0|     0|    11|   11|   3|
# | Israel|          Taekwondo|   0|     0|     1|    1|   4|
# +-------+-------------------+----+------+------+-----+----+
#
# +-----------+-------------------+----+------+------+-----+----+
# |    Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-----------+-------------------+----+------+------+-----+----+
# |South Korea|            Archery|   9|     0|     0|    9|   1|
# |South Korea|            Fencing|   4|     4|     9|   17|   2|
# |South Korea|Artistic Gymnastics|   1|     0|     1|    2|   3|
# |South Korea|               Judo|   0|     1|     2|    3|   4|
# |South Korea|          Taekwondo|   0|     1|     2|    3|   5|
# |South Korea|           Shooting|   0|     1|     0|    1|   6|
# |South Korea|          Badminton|   0|     0|     2|    2|   7|
# |South Korea|  Modern Pentathlon|   0|     0|     1|    1|   8|
# +-----------+-------------------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# | Mexico|     Football|   0|     0|    22|   22|   1|
# | Mexico|       Diving|   0|     0|     2|    2|   2|
# | Mexico|      Archery|   0|     0|     2|    2|   3|
# | Mexico|Weightlifting|   0|     0|     1|    1|   4|
# +-------+-------------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |Georgia|         Judo|   1|     3|     0|    4|   1|
# |Georgia|Weightlifting|   1|     0|     1|    2|   2|
# |Georgia|    Wrestling|   0|     2|     0|    2|   3|
# +-------+-------------+----+------+------+-----+----+
#
# +-------+-------+----+------+------+-----+----+
# |Country|  Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------+----+------+------+-----+----+
# |Estonia|Fencing|   4|     0|     1|    5|   1|
# +-------+-------+----+------+------+-----+----+
#
# +---------+-------------+----+------+------+-----+----+
# |  Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +---------+-------------+----+------+------+-----+----+
# |Indonesia|    Badminton|   2|     0|     1|    3|   1|
# |Indonesia|Weightlifting|   0|     1|     2|    3|   2|
# +---------+-------------+----+------+------+-----+----+
#
# +--------+---------+----+------+------+-----+----+
# | Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+---------+----+------+------+-----+----+
# |Mongolia|     Judo|   0|     1|     2|    3|   1|
# |Mongolia|Wrestling|   0|     0|     1|    1|   2|
# +--------+---------+----+------+------+-----+----+
#
# +----------+---------+----+------+------+-----+----+
# |   Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +----------+---------+----+------+------+-----+----+
# |Azerbaijan|   Karate|   0|     2|     0|    2|   1|
# |Azerbaijan|Wrestling|   0|     1|     2|    3|   2|
# |Azerbaijan|     Judo|   0|     0|     1|    1|   3|
# |Azerbaijan|   Boxing|   0|     0|     1|    1|   4|
# +----------+---------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Grenada|Athletics|   0|     0|     1|    1|   1|
# +-------+---------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# |Armenia|          Wrestling|   0|     1|     0|    1|   1|
# |Armenia|      Weightlifting|   0|     1|     0|    1|   2|
# |Armenia|Artistic Gymnastics|   0|     0|     1|    1|   3|
# |Armenia|             Boxing|   0|     0|     1|    1|   4|
# +-------+-------------------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Tunisia| Swimming|   1|     0|     0|    1|   1|
# |Tunisia|Taekwondo|   0|     1|     0|    1|   2|
# +-------+---------+----+------+------+-----+----+
#
# +-------+-------------+----+------+------+-----+----+
# |Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------+----+------+------+-----+----+
# |  Syria|Weightlifting|   0|     0|     1|    1|   1|
# +-------+-------------+----+------+------+-----+----+
#
# +------------+------+----+------+------+-----+----+
# |     Country| Sport|Gold|Silver|Bronze|Total|Rank|
# +------------+------+----+------+------+-----+----+
# |Saudi Arabia|Karate|   0|     1|     0|    1|   1|
# +------------+------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# | Uganda|Athletics|   2|     1|     1|    4|   1|
# +-------+---------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Namibia|Athletics|   0|     1|     0|    1|   1|
# +-------+---------+----+------+------+-----+----+
#
# +-----------+--------------------+----+------+------+-----+----+
# |    Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +-----------+--------------------+----+------+------+-----+----+
# |Switzerland|Cycling Mountain ...|   1|     2|     1|    4|   1|
# |Switzerland|              Tennis|   1|     2|     0|    3|   2|
# |Switzerland|            Shooting|   1|     0|     1|    2|   3|
# |Switzerland|        Cycling Road|   0|     1|     0|    1|   4|
# |Switzerland|            Swimming|   0|     0|     2|    2|   5|
# |Switzerland|    Beach Volleyball|   0|     0|     2|    2|   6|
# |Switzerland|Cycling BMX Frees...|   0|     0|     1|    1|   7|
# +-----------+--------------------+----+------+------+-----+----+
#
# +--------+---------+----+------+------+-----+----+
# | Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+---------+----+------+------+-----+----+
# |Ethiopia|Athletics|   1|     1|     2|    4|   1|
# +--------+---------+----+------+------+-----+----+
#
# +-------+--------------+----+------+------+-----+----+
# |Country|         Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------------+----+------+------+-----+----+
# | Latvia|3x3 Basketball|   4|     0|     0|    4|   1|
# | Latvia| Weightlifting|   0|     0|     1|    1|   2|
# +-------+--------------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Jamaica|Athletics|   9|     1|    11|   21|   1|
# +-------+---------+----+------+------+-----+----+
#
# +-------+-----------------+----+------+------+-----+----+
# |Country|            Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-----------------+----+------+------+-----+----+
# | Canada|         Football|  22|     0|     0|   22|   1|
# | Canada|           Rowing|   9|     0|     2|   11|   2|
# | Canada|        Athletics|   2|     1|     9|   12|   3|
# | Canada|         Swimming|   1|     7|     7|   15|   4|
# | Canada|    Cycling Track|   1|     0|     1|    2|   5|
# | Canada|    Weightlifting|   1|     0|     0|    1|   6|
# | Canada|           Diving|   0|     2|     0|    2|   7|
# | Canada|     Canoe Sprint|   0|     1|     2|    3|   8|
# | Canada|Baseball/Softball|   0|     0|    15|   15|   9|
# | Canada|             Judo|   0|     0|     2|    2|  10|
# +-------+-----------------+----+------+------+-----+----+
#
# +----------+-------------+----+------+------+-----+----+
# |   Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +----------+-------------+----+------+------+-----+----+
# |Uzbekistan|    Taekwondo|   1|     0|     0|    1|   1|
# |Uzbekistan|       Boxing|   1|     0|     0|    1|   2|
# |Uzbekistan|Weightlifting|   1|     0|     0|    1|   3|
# |Uzbekistan|    Wrestling|   0|     0|     1|    1|   4|
# |Uzbekistan|         Judo|   0|     0|     1|    1|   5|
# +----------+-------------+----+------+------+-----+----+
#
# +----------+---------+----+------+------+-----+----+
# |   Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +----------+---------+----+------+------+-----+----+
# |Kyrgyzstan|Wrestling|   0|     2|     1|    3|   1|
# +----------+---------+----+------+------+-----+----+
#
# +---------------+---------+----+------+------+-----+----+
# |        Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +---------------+---------+----+------+------+-----+----+
# |North Macedonia|Taekwondo|   0|     1|     0|    1|   1|
# +---------------+---------+----+------+------+-----+----+
#
# +--------------+------------+----+------+------+-----+----+
# |       Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +--------------+------------+----+------+------+-----+----+
# |Czech Republic|      Tennis|   2|     1|     0|    3|   1|
# |Czech Republic|    Shooting|   1|     1|     0|    2|   2|
# |Czech Republic|Canoe Slalom|   1|     1|     0|    2|   3|
# |Czech Republic|        Judo|   1|     0|     0|    1|   4|
# |Czech Republic|   Athletics|   0|     1|     1|    2|   5|
# |Czech Republic|Canoe Sprint|   0|     0|     2|    2|   6|
# |Czech Republic|     Fencing|   0|     0|     1|    1|   7|
# +--------------+------------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# | Brazil|           Football|  22|     0|     0|   22|   1|
# | Brazil|            Sailing|   2|     0|     0|    2|   2|
# | Brazil|             Boxing|   1|     1|     1|    3|   3|
# | Brazil|Artistic Gymnastics|   1|     1|     0|    2|   4|
# | Brazil|       Canoe Sprint|   1|     0|     0|    1|   5|
# | Brazil|  Marathon Swimming|   1|     0|     0|    1|   6|
# | Brazil|            Surfing|   1|     0|     0|    1|   7|
# | Brazil|         Volleyball|   0|    12|     0|   12|   8|
# | Brazil|      Skateboarding|   0|     3|     0|    3|   9|
# | Brazil|             Tennis|   0|     0|     2|    2|  10|
# | Brazil|               Judo|   0|     0|     2|    2|  11|
# | Brazil|          Athletics|   0|     0|     2|    2|  12|
# | Brazil|           Swimming|   0|     0|     2|    2|  13|
# +-------+-------------------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |  Kenya|Athletics|   4|     4|     2|   10|   1|
# +-------+---------+----+------+------+-----+----+
#
# +--------+--------------+----+------+------+-----+----+
# | Country|         Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+--------------+----+------+------+-----+----+
# |Slovenia|  Cycling Road|   1|     0|     1|    2|   1|
# |Slovenia|  Canoe Slalom|   1|     0|     0|    1|   2|
# |Slovenia|Sport Climbing|   1|     0|     0|    1|   3|
# |Slovenia|          Judo|   0|     1|     0|    1|   4|
# +--------+--------------+----+------+------+-----+----+
#
# +------------------+-----------------+----+------+------+-----+----+
# |           Country|            Sport|Gold|Silver|Bronze|Total|Rank|
# +------------------+-----------------+----+------+------+-----+----+
# |Dominican Republic|        Athletics|   0|     6|     0|    6|   1|
# |Dominican Republic|    Weightlifting|   0|     1|     1|    2|   2|
# |Dominican Republic|Baseball/Softball|   0|     0|    24|   24|   3|
# +------------------+-----------------+----+------+------+-----+----+
#
# +-------+-------------------+----+------+------+-----+----+
# |Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------------------+----+------+------+-----+----+
# |  Japan|  Baseball/Softball|  39|     0|     0|   39|   1|
# |  Japan|               Judo|   9|    13|     1|   23|   2|
# |  Japan|          Wrestling|   5|     1|     1|    7|   3|
# |  Japan|            Fencing|   4|     0|     0|    4|   4|
# |  Japan|      Skateboarding|   3|     1|     1|    5|   5|
# |  Japan|Artistic Gymnastics|   2|     4|     2|    8|   6|
# |  Japan|       Table Tennis|   2|     3|     4|    9|   7|
# |  Japan|           Swimming|   2|     1|     0|    3|   8|
# |  Japan|             Karate|   1|     1|     1|    3|   9|
# |  Japan|             Boxing|   1|     0|     2|    3|  10|
# |  Japan|         Basketball|   0|    12|     0|   12|  11|
# |  Japan|     Sport Climbing|   0|     1|     1|    2|  12|
# |  Japan|          Athletics|   0|     1|     1|    2|  13|
# |  Japan|            Surfing|   0|     1|     1|    2|  14|
# |  Japan|               Golf|   0|     1|     0|    1|  15|
# |  Japan|      Cycling Track|   0|     1|     0|    1|  16|
# |  Japan|            Archery|   0|     0|     4|    4|  17|
# |  Japan|          Badminton|   0|     0|     2|    2|  18|
# |  Japan|      Weightlifting|   0|     0|     1|    1|  19|
# +-------+-------------------+----+------+------+-----+----+
#
# +--------+---------+----+------+------+-----+----+
# | Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+---------+----+------+------+-----+----+
# |Botswana|Athletics|   0|     0|     6|    6|   1|
# +--------+---------+----+------+------+-----+----+
#
# +-----------+--------------------+----+------+------+-----+----+
# |    Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +-----------+--------------------+----+------+------+-----+----+
# |New Zealand|        Rugby Sevens|  13|    13|     0|   26|   1|
# |New Zealand|              Rowing|  12|    11|     0|   23|   2|
# |New Zealand|        Canoe Sprint|   4|     0|     0|    4|   3|
# |New Zealand|       Cycling Track|   0|     2|     0|    2|   4|
# |New Zealand|             Sailing|   0|     2|     0|    2|   5|
# |New Zealand|              Tennis|   0|     0|     2|    2|   6|
# |New Zealand|           Athletics|   0|     0|     2|    2|   7|
# |New Zealand|              Boxing|   0|     0|     1|    1|   8|
# |New Zealand|           Triathlon|   0|     0|     1|    1|   9|
# |New Zealand|Trampoline Gymnas...|   0|     0|     1|    1|  10|
# |New Zealand|                Golf|   0|     0|     1|    1|  11|
# +-----------+--------------------+----+------+------+-----+----+
#
# +-------+------------+----+------+------+-----+----+
# |Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+------------+----+------+------+-----+----+
# | Poland|   Athletics|  14|     6|     3|   23|   1|
# | Poland|      Rowing|   0|     4|     0|    4|   2|
# | Poland|Canoe Sprint|   0|     2|     4|    6|   3|
# | Poland|     Sailing|   0|     2|     0|    2|   4|
# | Poland|   Wrestling|   0|     0|     1|    1|   5|
# +-------+------------+----+------+------+-----+----+
#
# +--------+------------+----+------+------+-----+----+
# | Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+------------+----+------+------+-----+----+
# |Portugal|   Athletics|   1|     1|     0|    2|   1|
# |Portugal|        Judo|   0|     0|     1|    1|   2|
# |Portugal|Canoe Sprint|   0|     0|     1|    1|   3|
# +--------+------------+----+------+------+-----+----+
#
# +---------+--------------------+----+------+------+-----+----+
# |  Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +---------+--------------------+----+------+------+-----+----+
# |Australia|            Swimming|  20|     3|    30|   53|   1|
# |Australia|              Rowing|   8|     0|     8|   16|   2|
# |Australia|             Sailing|   3|     0|     0|    3|   3|
# |Australia|        Canoe Sprint|   2|     0|     0|    2|   4|
# |Australia|        Canoe Slalom|   1|     0|     1|    2|   5|
# |Australia|       Skateboarding|   1|     0|     0|    1|   6|
# |Australia|Cycling BMX Frees...|   1|     0|     0|    1|   7|
# |Australia|              Hockey|   0|    18|     0|   18|   8|
# |Australia|          Equestrian|   0|     4|     1|    5|   9|
# |Australia|    Beach Volleyball|   0|     2|     0|    2|  10|
# |Australia|           Athletics|   0|     1|     2|    3|  11|
# |Australia|          Basketball|   0|     0|    12|   12|  12|
# |Australia|       Cycling Track|   0|     0|     6|    6|  13|
# |Australia|              Tennis|   0|     0|     2|    2|  14|
# |Australia|   Marathon Swimming|   0|     0|     1|    1|  15|
# |Australia|        Cycling Road|   0|     0|     1|    1|  16|
# |Australia|             Surfing|   0|     0|     1|    1|  17|
# |Australia|              Boxing|   0|     0|     1|    1|  18|
# |Australia|              Diving|   0|     0|     1|    1|  19|
# +---------+--------------------+----+------+------+-----+----+
#
# +-------+-------+----+------+------+-----+----+
# |Country|  Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-------+----+------+------+-----+----+
# |Romania| Rowing|   2|     6|     0|    8|   1|
# |Romania|Fencing|   0|     1|     0|    1|   2|
# +-------+-------+----+------+------+-----+----+
#
# +--------+-------------------+----+------+------+-----+----+
# | Country|              Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+-------------------+----+------+------+-----+----+
# |Bulgaria|Rhythmic Gymnastics|   5|     0|     0|    5|   1|
# |Bulgaria|             Boxing|   1|     0|     0|    1|   2|
# |Bulgaria|             Karate|   1|     0|     0|    1|   3|
# |Bulgaria|           Shooting|   0|     1|     0|    1|   4|
# |Bulgaria|          Wrestling|   0|     0|     2|    2|   5|
# +--------+-------------------+----+------+------+-----+----+
#
# +-------+--------------+----+------+------+-----+----+
# |Country|         Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------------+----+------+------+-----+----+
# |Austria|  Cycling Road|   1|     0|     0|    1|   1|
# |Austria|          Judo|   0|     1|     1|    2|   2|
# |Austria|     Athletics|   0|     0|     1|    1|   3|
# |Austria|        Karate|   0|     0|     1|    1|   4|
# |Austria|        Rowing|   0|     0|     1|    1|   5|
# |Austria|Sport Climbing|   0|     0|     1|    1|   6|
# +-------+--------------+----+------+------+-----+----+
#
# +-------+-----------------+----+------+------+-----+----+
# |Country|            Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-----------------+----+------+------+-----+----+
# |  Egypt|           Karate|   1|     0|     1|    2|   1|
# |  Egypt|Modern Pentathlon|   0|     1|     0|    1|   2|
# |  Egypt|        Taekwondo|   0|     0|     2|    2|   3|
# |  Egypt|        Wrestling|   0|     0|     1|    1|   4|
# +-------+-----------------+----+------+------+-----+----+
#
# +----------+-------------+----+------+------+-----+----+
# |   Country|        Sport|Gold|Silver|Bronze|Total|Rank|
# +----------+-------------+----+------+------+-----+----+
# |Kazakhstan|       Boxing|   0|     0|     2|    2|   1|
# |Kazakhstan|       Karate|   0|     0|     2|    2|   2|
# |Kazakhstan|Weightlifting|   0|     0|     2|    2|   3|
# |Kazakhstan|    Wrestling|   0|     0|     1|    1|   4|
# |Kazakhstan|         Judo|   0|     0|     1|    1|   5|
# +----------+-------------+----+------+------+-----+----+
#
# +-------+--------------+----+------+------+-----+----+
# |Country|         Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+--------------+----+------+------+-----+----+
# | Serbia|    Water Polo|  13|     0|     0|   13|   1|
# | Serbia|     Taekwondo|   1|     0|     1|    2|   2|
# | Serbia|        Karate|   1|     0|     0|    1|   3|
# | Serbia|      Shooting|   0|     1|     1|    2|   4|
# | Serbia|    Volleyball|   0|     0|    12|   12|   5|
# | Serbia|3x3 Basketball|   0|     0|     4|    4|   6|
# | Serbia|     Wrestling|   0|     0|     1|    1|   7|
# +-------+--------------+----+------+------+-----+----+
#
# +------------+--------+----+------+------+-----+----+
# |     Country|   Sport|Gold|Silver|Bronze|Total|Rank|
# +------------+--------+----+------+------+-----+----+
# |South Africa|Swimming|   1|     1|     0|    2|   1|
# |South Africa| Surfing|   0|     1|     0|    1|   2|
# +------------+--------+----+------+------+-----+----+
#
# +------------+---------+----+------+------+-----+----+
# |     Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +------------+---------+----+------+------+-----+----+
# |Burkina Faso|Athletics|   0|     0|     1|    1|   1|
# +------------+---------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Bermuda|Triathlon|   1|     0|     0|    1|   1|
# +-------+---------+----+------+------+-----+----+
#
# +-------+---------+----+------+------+-----+----+
# |Country|    Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+---------+----+------+------+-----+----+
# |Bahrain|Athletics|   0|     1|     0|    1|   1|
# +-------+---------+----+------+------+-----+----+
#
# +--------+------------------+----+------+------+-----+----+
# | Country|             Sport|Gold|Silver|Bronze|Total|Rank|
# +--------+------------------+----+------+------+-----+----+
# |Colombia|         Athletics|   0|     2|     0|    2|   1|
# |Colombia|Cycling BMX Racing|   0|     1|     1|    2|   2|
# |Colombia|     Weightlifting|   0|     1|     0|    1|   3|
# +--------+------------------+----+------+------+-----+----+
#
# +-------+-----------------+----+------+------+-----+----+
# |Country|            Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+-----------------+----+------+------+-----+----+
# |Hungary|     Canoe Sprint|   6|     2|     2|   10|   1|
# |Hungary|          Fencing|   1|     1|     4|    6|   2|
# |Hungary|        Wrestling|   1|     1|     0|    2|   3|
# |Hungary|         Swimming|   1|     1|     0|    2|   4|
# |Hungary|Marathon Swimming|   0|     1|     0|    1|   5|
# |Hungary|          Sailing|   0|     1|     0|    1|   6|
# |Hungary|       Water Polo|   0|     0|    26|   26|   7|
# |Hungary|             Judo|   0|     0|     1|    1|   8|
# |Hungary|           Karate|   0|     0|     1|    1|   9|
# |Hungary|Modern Pentathlon|   0|     0|     1|    1|  10|
# +-------+-----------------+----+------+------+-----+----+
#
# +-------+------------+----+------+------+-----+----+
# |Country|       Sport|Gold|Silver|Bronze|Total|Rank|
# +-------+------------+----+------+------+-----+----+
# |Moldova|Canoe Sprint|   0|     0|     1|    1|   1|
# +-------+------------+----+------+------+-----+----+
#
# +-----------+------------------+----+------+------+-----+----+
# |    Country|             Sport|Gold|Silver|Bronze|Total|Rank|
# +-----------+------------------+----+------+------+-----+----+
# |Netherlands|            Hockey|  18|     0|     0|   18|   1|
# |Netherlands|     Cycling Track|   6|     1|     2|    9|   2|
# |Netherlands|            Rowing|   4|     6|     4|   14|   3|
# |Netherlands|         Athletics|   2|     8|     3|   13|   4|
# |Netherlands|      Cycling Road|   1|     2|     1|    4|   5|
# |Netherlands|           Sailing|   1|     0|     3|    4|   6|
# |Netherlands|Cycling BMX Racing|   1|     0|     1|    2|   7|
# |Netherlands|           Archery|   0|     2|     0|    2|   8|
# |Netherlands|          Swimming|   0|     2|     0|    2|   9|
# |Netherlands| Marathon Swimming|   0|     1|     0|    1|  10|
# |Netherlands|        Equestrian|   0|     0|     1|    1|  11|
# |Netherlands|            Boxing|   0|     0|     1|    1|  12|
# |Netherlands|              Judo|   0|     0|     1|    1|  13|
# +-----------+------------------+----+------+------+-----+----+

# %% [markdown]
# # 4. Dataframe showing medal counts of each atheletes and their ranks

# %%
# Group the DataFrame by "Name" (player name) and calculate medal counts
result_df = df.groupBy("Name").agg(
    count(when(df["Medal"] == "Gold", True)).alias("Gold"),
    count(when(df["Medal"] == "Silver", True)).alias("Silver"),
    count(when(df["Medal"] == "Bronze", True)).alias("Bronze"),
    count(when(df['Medal'] != 'None', True)).alias('Total'),
    max('Country').alias('Country'),
    max('Gender').alias('Gender'),
    collect_list(when(df['Medal'] != 'None', df['Event'])).alias("Sport Events")  # Collect sports with medals in an array
)

# Filter out players with a total medal count of 0
result_df = result_df.filter(col('Total') > 0)

# Define a Window specification for ranking based on total medal counts
window_spec = Window.orderBy(
    col("Gold").desc(), col("Silver").desc(), col("Bronze").desc(), col("Total").desc()
)

# Add a "Rank" column based on total medal counts
result_df = result_df.withColumn("Rank", F.row_number().over(window_spec)).select('Rank','Name','Gender','Country','Gold','Silver','Bronze','Total','Sport Events')

# Show the result DataFrame
result_df.show(truncate=False)
# Out:
# +----+----------------------+------+-------------+----+------+------+-----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Rank|Name                  |Gender|Country      |Gold|Silver|Bronze|Total|Sport Events                                                                                                                                                                                                               |
# +----+----------------------+------+-------------+----+------+------+-----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |1   |DRESSEL Caeleb        |M     |United States|5   |0     |0     |5    |[Men's 50m Freestyle, Men's 100m Freestyle, Men's 100m Butterfly, Men's 4 x 100m Freestyle Relay Team, Men's 4 x 100m Medley Relay Team]                                                                                   |
# |2   |McKEON Emma           |F     |Australia    |4   |0     |3     |7    |[Women's 50m Freestyle, Women's 100m Freestyle, Women's 100m Butterfly, Women's 4 x 100m Freestyle Relay Team, Women's 4 x 200m Freestyle Relay Team, Women's 4 x 100m Medley Relay Team, Mixed 4 x 100m Medley Relay Team]|
# |3   |McKEOWN Kaylee        |F     |Australia    |3   |0     |1     |4    |[Women's 100m Backstroke, Women's 200m Backstroke, Women's 4 x 100m Medley Relay Team, Mixed 4 x 100m Medley Relay Team]                                                                                                   |
# |4   |CARRINGTON Lisa       |F     |New Zealand  |3   |0     |0     |3    |[Women's Kayak Single 200m, Women's Kayak Single 500m, Women's Kayak Double 500m Team]                                                                                                                                     |
# |5   |AN San                |F     |South Korea  |3   |0     |0     |3    |[Women's Individual, Women's Team, Mixed Team]                                                                                                                                                                             |
# |6   |THOMPSON-HERAH Elaine |F     |Jamaica      |3   |0     |0     |3    |[Women's 100m, Women's 200m, Women's 4 x 100m Relay Team]                                                                                                                                                                  |
# |7   |LEDECKY Kathleen      |F     |United States|2   |2     |0     |4    |[Women's 400m Freestyle, Women's 800m Freestyle, Women's 1500m Freestyle, Women's 4 x 200m Freestyle Relay Team]                                                                                                           |
# |8   |ZHANG Yufei           |F     |China        |2   |2     |0     |4    |[Women's 100m Butterfly, Women's 200m Butterfly, Women's 4 x 200m Freestyle Relay Team, Mixed 4 x 100m Medley Relay Team]                                                                                                  |
# |9   |TITMUS Ariarne        |F     |Australia    |2   |1     |1     |4    |[Women's 200m Freestyle, Women's 400m Freestyle, Women's 800m Freestyle, Women's 4 x 200m Freestyle Relay Team]                                                                                                            |
# |10  |BATSARASHKINA Vitalina|F     |Russia       |2   |1     |0     |3    | Air Pistol Women, 25m Pistol Women, 10m Air Pistol Mixed Team]                                                                                                                                                        |
# |11  |GUY James             |M     |Great Britain|2   |1     |0     |3    |[Men's 4 x 200m Freestyle Relay Team, Men's 4 x 100m Medley Relay Team, Mixed 4 x 100m Medley Relay Team]                                                                                                                  |
# |12  |HASHIMOTO Daiki       |M     |Japan        |2   |1     |0     |3    |[Men's All-Around, Men's Horizontal Bar, Men's Team]                                                                                                                                                                       |
# |13  |PEATY Adam            |M     |Great Britain|2   |1     |0     |3    |[Men's 100m Breaststroke, Men's 4 x 100m Medley Relay Team, Mixed 4 x 100m Medley Relay Team]                                                                                                                              |
# |14  |RYLOV Evgeny          |M     |Russia       |2   |1     |0     |3    |[Men's 100m Backstroke, Men's 200m Backstroke, Men's 4 x 200m Freestyle Relay Team]                                                                                                                                        |
# |15  |CAMPBELL Cate         |F     |Australia    |2   |0     |1     |3    |[Women's 100m Freestyle, Women's 4 x 100m Freestyle Relay Team, Women's 4 x 100m Medley Relay Team]                                                                                                                        |
# |16  |HASSAN Sifan          |F     |Netherlands  |2   |0     |1     |3    |[Women's 1500m, Women's 5000m, Women's 10,000m]                                                                                                                                                                            |
# |17  |LAVREYSEN Harrie      |M     |Netherlands  |2   |0     |1     |3    |[Men's Team Sprint Team, Men's Sprint, Men's Keirin]                                                                                                                                                                       |
# |18  |O'CALLAGHAN Mollie    |F     |Australia    |2   |0     |1     |3    |[Women's 4 x 100m Freestyle Relay Team, Women's 4 x 200m Freestyle Relay Team, Women's 4 x 100m Medley Relay Team]                                                                                                         |
# |19  |JACOBS Lamont Marcell |M     |Italy        |2   |0     |0     |2    |[Men's 100m, Men's 4 x 100m Relay Team]                                                                                                                                                                                    |
# |20  |KIM Je Deok           |M     |South Korea  |2   |0     |0     |2    |[Men's Team, Mixed Team]                                                                                                                                                                                                   |
# +----+----------------------+------+-------------+----+------+------+-----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# # 5. Dataframe showing Medal counts of  Top atheletes from each country who have won medals

# %%
# Group the DataFrame by "Name" (player name) and calculate medal counts
result_df = df.groupBy("Name").agg(
    count(when(df["Medal"] == "Gold", True)).alias("Gold"),
    count(when(df["Medal"] == "Silver", True)).alias("Silver"),
    count(when(df["Medal"] == "Bronze", True)).alias("Bronze"),
    count(when(df['Medal'] != 'None', True)).alias('Total'),
    max('Country').alias('Country'),
    max('Gender').alias('Gender'),
    collect_list(when(df['Medal'] != 'None', df['Event'])).alias("Events")  # Collect events with medals in an array
)

# Filter out players with a total medal count of 0
result_df = result_df.filter(col('Total') > 0)
result_df.filter(col('Total')==0).show()
# Get the unique list of countries from the DataFrame
unique_countries = [row['Country'] for row in result_df.select('Country').distinct().collect()]

# Create a dictionary to store DataFrames for each country
country_dataframes = {}

# Iterate through each country
for country in unique_countries:
    # Filter the DataFrame for the current country
    country_df = result_df.filter(result_df["Country"] == country)


    # Filter for the top 3 athletes in the country
    window_spec = Window.orderBy(
            col("Gold").desc(), col("Silver").desc(), col("Bronze").desc(), col("Total").desc()
        )
    player_df = country_df.withColumn("Rank", F.row_number().over(window_spec))
    top_3_athletes_df = player_df.filter(col("Rank") <= 3).select('Rank','Name','Country','Gender','Gold','Silver','Bronze','Total','Events')
    top_3_athletes_df.show()
    # Store the result DataFrame in the dictionary using the country name as the key
    country_dataframes[country] = top_3_athletes_df
# Out:
# +----+----+------+------+-----+-------+------+------+
# |Name|Gold|Silver|Bronze|Total|Country|Gender|Events|
# +----+----+------+------+-----+-------+------+------+
# +----+----+------+------+-----+-------+------+------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|BATSARASHKINA Vit...| Russia|     F|   2|     1|     0|    3| Air Pistol W...|
# |   2|        RYLOV Evgeny| Russia|     M|   2|     1|     0|    3|[Men's 100m Backs...|
# |   3|KOLESNICHENKO Sve...| Russia|     F|   2|     0|     0|    2|   [Duet Team, Team]|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------+--------------+------+----+------+------+-----+--------------------+
# |Rank|          Name|       Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------+--------------+------+----+------+------+-----+--------------------+
# |   1|KUO Hsing-Chun|Chinese Taipei|     F|   1|     0|     0|    1|      [Women's 59kg]|
# |   2|      LEE Yang|Chinese Taipei|     M|   1|     0|     0|    1|[Men's Doubles Team]|
# |   3|  WANG Chi-Lin|Chinese Taipei|     M|   1|     0|     0|    1|[Men's Doubles Team]|
# +----+--------------+--------------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|    FREDRICSON Peder| Sweden|     M|   1|     1|     0|    2|[Jumping Team, Ju...|
# |   2|BARYARD-JOHNSSON ...| Sweden|     F|   1|     0|     0|    1|      [Jumping Team]|
# |   3|BENGTSSON Rolf-Goran| Sweden|     M|   1|     0|     0|    1|      [Jumping Team]|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------+-----------+------+----+------+------+-----+--------------------+
# |Rank|          Name|    Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------+-----------+------+----+------+------+-----+--------------------+
# |   1|  DIAZ Hidilyn|Philippines|     F|   1|     0|     0|    1|      [Women's 55kg]|
# |   2|  PAALAM Carlo|Philippines|     M|   0|     1|     0|    1|[Men's Fly (48-52...|
# |   3|PETECIO Nesthy|Philippines|     F|   0|     1|     0|    1|[Women's Feather ...|
# +----+--------------+-----------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |Rank|                Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |   1|AWANG Mohd Azizul...|Malaysia|     M|   0|     1|     0|    1|      [Men's Keirin]|
# |   2|          CHIA Aaron|Malaysia|     M|   0|     0|     1|    1|[Men's Doubles Team]|
# |   3|        SOH Wooi Yik|Malaysia|     M|   0|     0|     1|    1|[Men's Doubles Team]|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+----------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|    Events|
# +----+--------------------+-------+------+----+------+------+-----+----------+
# |   1|BALEIWAIRIKI Iose...|   Fiji|     M|   1|     0|     0|    1|[Men Team]|
# |   2|    BOLACA Napolioni|   Fiji|     M|   1|     0|     0|    1|[Men Team]|
# |   3|     BOTITU Vilimoni|   Fiji|     M|   1|     0|     0|    1|[Men Team]|
# +----+--------------------+-------+------+----+------+------+-----+----------+
#
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|              Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |   1|        GAZOZ Mete| Turkey|     M|   1|     0|     0|    1|  [Men's Individual]|
# |   2| SURMENELI Busenaz| Turkey|     F|   1|     0|     0|    1|[Women's Welter (...|
# |   3|CAKIROGLU Buse Naz| Turkey|     F|   0|     1|     0|    1|[Women's Fly (48-...|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|von BREDOW-WERNDL...|Germany|     F|   2|     0|     0|    2|[Dressage Team, D...|
# |   2|       WERTH Isabell|Germany|     F|   1|     1|     0|    2|[Dressage Team, D...|
# |   3|   WELLBROCK Florian|Germany|     M|   1|     0|     1|    2|[Men's 10km, Men'...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|   ELSHARABATY Saleh| Jordan|     M|   0|     1|     0|    1|         [Men -80kg]|
# |   2|ALMASATFA Abdel R...| Jordan|     M|   0|     0|     1|    1|[Men's Kumite -67kg]|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-----------+-----------+------+----+------+------+-----+-------------+
# |Rank|       Name|    Country|Gender|Gold|Silver|Bronze|Total|       Events|
# +----+-----------+-----------+------+----+------+------+-----+-------------+
# |   1|GBAGBI Ruth|Ivory Coast|     F|   0|     0|     1|    1|[Women -67kg]|
# +----+-----------+-----------+------+----+------+------+-----+-------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1| AGBEGNENOU Clarisse| France|     F|   2|     0|     0|    2|[Women -63 kg, Mi...|
# |   2|    BUCHARD Amandine| France|     F|   1|     1|     0|    2|[Women -52 kg, Mi...|
# |   3|CYSIQUE Sarah Leonie| France|     F|   1|     1|     0|    2|[Women -57 kg, Mi...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|   NTOUSKOS Stefanos| Greece|     M|   1|     0|     0|    1|[Men's Single Scu...|
# |   2| TENTOGLOU Miltiadis| Greece|     M|   1|     0|     0|    1|   [Men's Long Jump]|
# |   3|ARGYROPOULOS KANA...| Greece|     M|   0|     1|     0|    1|          [Men Team]|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+----------------+-------+------+----+------+------+-----+--------------+
# |Rank|            Name|Country|Gender|Gold|Silver|Bronze|Total|        Events|
# +----+----------------+-------+------+----+------+------+-----+--------------+
# |   1|    GJAKOVA Nora| Kosovo|     F|   1|     0|     0|    1|[Women -57 kg]|
# |   2|KRASNIQI Distria| Kosovo|     F|   1|     0|     0|    1|[Women -48 kg]|
# +----+----------------+-------+------+----+------+------+-----+--------------+
#
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |Rank|                Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |   1|REHAK STEFECEKOVA...|Slovakia|     F|   1|     0|     0|    1|        [Trap Women]|
# |   2|        GRIGAR Jakub|Slovakia|     M|   0|     1|     0|    1|       [Men's Kayak]|
# |   3|      SABBATINI Rory|Slovakia|     M|   0|     1|     0|    1|[Men's Individual...|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+----------------+------+----+------+------+-----+--------------------+
# |Rank|                Name|         Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+----------------+------+----+------+------+-----+--------------------+
# |   1|      CHEUNG Ka Long|Hong Kong, China|     M|   1|     0|     0|    1|[Men's Foil Indiv...|
# |   2|HAUGHEY Siobhan B...|Hong Kong, China|     F|   0|     2|     0|    2|[Women's 100m Fre...|
# |   3|         DOO Hoi Kem|Hong Kong, China|     F|   0|     0|     1|    1|      [Women's Team]|
# +----+--------------------+----------------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+---------+------+----+------+------+-----+------------+
# |Rank|                Name|  Country|Gender|Gold|Silver|Bronze|Total|      Events|
# +----+--------------------+---------+------+----+------+------+-----+------------+
# |   1|ALBERTARRIO Agustina|Argentina|     F|   0|     1|     0|    1|[Women Team]|
# |   2|     ALONSO Agostina|Argentina|     F|   0|     1|     0|    1|[Women Team]|
# |   3|BARRIONUEVO Maria...|Argentina|     F|   0|     1|     0|    1|[Women Team]|
# +----+--------------------+---------+------+----+------+------+-----+------------+
#
# +----+----------------+-------+------+----+------+------+-----+----------+
# |Rank|            Name|Country|Gender|Gold|Silver|Bronze|Total|    Events|
# +----+----------------+-------+------+----+------+------+-----+----------+
# |   1|BOCCARD Gauthier|Belgium|     M|   1|     0|     0|    1|[Men Team]|
# |   2|  BOON Tom Alain|Belgium|     M|   1|     0|     0|    1|[Men Team]|
# |   3|   BRIELS Thomas|Belgium|     M|   1|     0|     0|    1|[Men Team]|
# +----+----------------+-------+------+----+------+------+-----+----------+
#
# +----+------------------+----------+------+----+------+------+-----+--------------------+
# |Rank|              Name|   Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------------+----------+------+----+------+------+-----+--------------------+
# |   1|PERILLI Alessandra|San Marino|     F|   0|     1|     1|    2|[Trap Women, Trap...|
# |   2|  BERTI Gian Marco|San Marino|     M|   0|     1|     0|    1|   [Trap Mixed Team]|
# |   3| AMINE Myles Nazem|San Marino|     M|   0|     0|     1|    1|[Men's Freestyle ...|
# +----+------------------+----------+------+----+------+------+-----+--------------------+
#
# +----+----------+-------------+------+----+------+------+-----+--------------------+
# |Rank|      Name|      Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------+-------------+------+----+------+------+-----+--------------------+
# |   1| GUY James|Great Britain|     M|   2|     1|     0|    3|[Men's 4 x 200m F...|
# |   2|PEATY Adam|Great Britain|     M|   2|     1|     0|    3|[Men's 100m Breas...|
# |   3|  DEAN Tom|Great Britain|     M|   2|     0|     0|    2|[Men's 200m Frees...|
# +----+----------+-------------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+-----------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|           Events|
# +----+--------------------+-------+------+----+------+------+-----+-----------------+
# |   1|  BARSHIM Mutaz Essa|  Qatar|     M|   1|     0|     0|    1|[Men's High Jump]|
# |   2|ELBAKH Fares Ibra...|  Qatar|     M|   1|     0|     0|    1|     [Men's 96kg]|
# |   3|         TIJAN Ahmed|  Qatar|     M|   0|     0|     1|    1|       [Men Team]|
# +----+--------------------+-------+------+----+------+------+-----+-----------------+
#
# +----+--------------------+-------+------+----+------+------+-----+-----------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|           Events|
# +----+--------------------+-------+------+----+------+------+-----+-----------------+
# |   1|     CARAPAZ Richard|Ecuador|     M|   1|     0|     0|    1|[Men's Road Race]|
# |   2|DAJOMES BARRERA N...|Ecuador|     F|   1|     0|     0|    1|   [Women's 76kg]|
# |   3|SALAZAR ARCE Tama...|Ecuador|     F|   0|     1|     0|    1|   [Women's 87kg]|
# +----+--------------------+-------+------+----+------+------+-----+-----------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|      MATTSSON Matti|Finland|     M|   0|     0|     1|    1|[Men's 200m Breas...|
# |   2|POTKONEN Mira Mar...|Finland|     F|   0|     0|     1|    1|[Women's Light (5...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------+-------+------+----+------+------+-----+--------------------+
# |Rank|        Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------+-------+------+----+------+------+-----+--------------------+
# |   1|TAKYI Samuel|  Ghana|     M|   0|     0|     1|    1|[Men's Feather (5...|
# +----+------------+-------+------+----+------+------+-----+--------------------+
#
# +----+----------------+-------------+------+----+------+------+-----+--------------------+
# |Rank|            Name|      Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+-------------+------+----+------+------+-----+--------------------+
# |   1|  DRESSEL Caeleb|United States|     M|   5|     0|     0|    5|[Men's 50m Freest...|
# |   2|LEDECKY Kathleen|United States|     F|   2|     2|     0|    4|[Women's 400m Fre...|
# |   3|      APPLE Zach|United States|     M|   2|     0|     0|    2|[Men's 4 x 100m F...|
# +----+----------------+-------------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|       CHOPRA Neeraj|  India|     M|   1|     0|     0|    1|[Men's Javelin Th...|
# |   2|MIRABAI Chanu Sai...|  India|     F|   0|     1|     0|    1|      [Women's 49kg]|
# |   3|          RAVI Kumar|  India|     M|   0|     1|     0|    1|[Men's Freestyle ...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-----------+-------+------+----+------+------+-----+--------------------+
# |Rank|       Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-----------+-------+------+----+------+------+-----+--------------------+
# |   1|ZHANG Yufei|  China|     F|   2|     2|     0|    4|[Women's 100m But...|
# |   2|  CHEN Meng|  China|     F|   2|     0|     0|    2|[Women's Singles,...|
# |   3|    MA Long|  China|     M|   2|     0|     0|    2|[Men's Singles, M...|
# +----+-----------+-------+------+----+------+------+-----+--------------------+
#
# +----+-------------------+-------+------+----+------+------+-----+--------------+
# |Rank|               Name|Country|Gender|Gold|Silver|Bronze|Total|        Events|
# +----+-------------------+-------+------+----+------+------+-----+--------------+
# |   1|    GARDINER Steven|Bahamas|     M|   1|     0|     0|    1|  [Men's 400m]|
# |   2|MILLER-UIBO Shaunae|Bahamas|     F|   1|     0|     0|    1|[Women's 400m]|
# +----+-------------------+-------+------+----+------+------+-----+--------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|    LITVINOVICH Ivan|Belarus|     M|   1|     0|     0|    1|               [Men]|
# |   2|KADZIMAHAMEDAU Ma...|Belarus|     M|   0|     1|     0|    1|[Men's Freestyle ...|
# |   3|     KHUDZENKA Volha|Belarus|     F|   0|     1|     0|    1|[Women's Kayak Fo...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------------+-------+------+----+------+------+-----+-----------+
# |Rank|              Name|Country|Gender|Gold|Silver|Bronze|Total|     Events|
# +----+------------------+-------+------+----+------+------+-----+-----------+
# |   1|ALRASHIDI Abdullah| Kuwait|     M|   0|     0|     1|    1|[Skeet Men]|
# +----+------------------+-------+------+----+------+------+-----+-----------+
#
# +----+--------------------+-----------+------+----+------+------+-----+--------------------+
# |Rank|                Name|    Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-----------+------+----+------+------+-----+--------------------+
# |   1|CAMACHO-QUINN Jas...|Puerto Rico|     F|   1|     0|     0|    1|[Women's 100m Hur...|
# +----+--------------------+-----------+------+----+------+------+-----+--------------------+
#
# +----+-------------+-------+------+----+------+------+-----+--------------------+
# |Rank|         Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-------------+-------+------+----+------+------+-----+--------------------+
# |   1|  JELIC Matea|Croatia|     F|   1|     0|     0|    1|       [Women -67kg]|
# |   2|MEKTIC Nikola|Croatia|     M|   1|     0|     0|    1|[Men's Doubles Team]|
# |   3|   PAVIC Mate|Croatia|     M|   1|     0|     0|    1|[Men's Doubles Team]|
# +----+-------------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|              Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |   1|OBORUDUDU Blessing|Nigeria|     F|   0|     1|     0|    1|[Women's Freestyl...|
# |   2|         BRUME Ese|Nigeria|     F|   0|     0|     1|    1| [Women's Long Jump]|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|JACOBS Lamont Mar...|  Italy|     M|   2|     0|     0|    2|[Men's 100m, Men'...|
# |   2|        VIVIANI Elia|  Italy|     M|   1|     0|     1|    2|[Men's Team Pursu...|
# |   3|      BANTI Caterina|  Italy|     F|   1|     0|     0|    1|[Mixed Multihull ...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------------+---------+------+----+------+------+-----+--------------------+
# |Rank|              Name|  Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------------+---------+------+----+------+------+-----+--------------------+
# |   1|ASADAUSKAITE Laura|Lithuania|     F|   0|     1|     0|    1|[Women's Individual]|
# +----+------------------+---------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|            Events|
# +----+--------------------+-------+------+----+------+------+-----+------------------+
# |   1|BLUMMENFELT Kristian| Norway|     M|   1|     0|     0|    1|[Men's Individual]|
# |   2|  INGEBRIGTSEN Jakob| Norway|     M|   1|     0|     0|    1|     [Men's 1500m]|
# |   3| MOL Anders Berntsen| Norway|     M|   1|     0|     0|    1|        [Men Team]|
# +----+--------------------+-------+------+----+------+------+-----+------------------+
#
# +----+--------------+------------+------+----+------+------+-----+--------------+
# |Rank|          Name|     Country|Gender|Gold|Silver|Bronze|Total|        Events|
# +----+--------------+------------+------+----+------+------+-----+--------------+
# |   1|GURYEVA Polina|Turkmenistan|     F|   0|     1|     0|    1|[Women's 59kg]|
# +----+--------------+------------+------+----+------+------+-----+--------------+
#
# +----+-------------------+-------+------+----+------+------+-----+-----------------+
# |Rank|               Name|Country|Gender|Gold|Silver|Bronze|Total|           Events|
# +----+-------------------+-------+------+----+------+------+-----+-----------------+
# |   1|  FERNANDEZ Alberto|  Spain|     M|   1|     0|     0|    1|[Trap Mixed Team]|
# |   2|      GALVEZ Fatima|  Spain|     F|   1|     0|     0|    1|[Trap Mixed Team]|
# |   3|GINES LOPEZ Alberto|  Spain|     M|   1|     0|     0|    1| [Men's Combined]|
# +----+-------------------+-------+------+----+------+------+-----+-----------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|           CRUZ Andy|   Cuba|     M|   1|     0|     0|    1|[Men's Light (57-...|
# |   2|     IGLESIAS Roniel|   Cuba|     M|   1|     0|     0|    1|[Men's Welter (63...|
# |   3|JORGE ENRIQUEZ Fe...|   Cuba|     M|   1|     0|     0|    1|[Men's Canoe Doub...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|               Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
# |   1|HANSEN Lasse Norman|Denmark|     M|   1|     1|     0|    2|[Men's Team Pursu...|
# |   2|     MORKOV Michael|Denmark|     M|   1|     1|     0|    2|[Men's Team Pursu...|
# |   3|     AXELSEN Viktor|Denmark|     M|   1|     0|     0|    1|     [Men's Singles]|
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|               Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
# |   1|     FOROUGHI Javad|   Iran|     M|   1|     0|     0|    1| Air Pistol Men]|
# |   2|    GANJZADEH Sajad|   Iran|     M|   1|     0|     0|    1|[Men's Kumite +75kg]|
# |   3|GERAEI Mohammadreza|   Iran|     M|   1|     0|     0|    1|[Men's Greco-Roma...|
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|HARRINGTON Kellie...|Ireland|     F|   1|     0|     0|    1|[Women's Light (5...|
# |   2|    Mc CARTHY Fintan|Ireland|     M|   1|     0|     0|    1|[Lightweight Men'...|
# |   3|      O'DONOVAN Paul|Ireland|     M|   1|     0|     0|    1|[Lightweight Men'...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |Rank|                Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |   1|WONGPATTANAKIT Pa...|Thailand|     F|   1|     0|     0|    1|       [Women -49kg]|
# |   2|  SEESONDEE Sudaporn|Thailand|     F|   0|     0|     1|    1|[Women's Light (5...|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
#
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|               Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
# |   1|EL BAKKALI Soufiane|Morocco|     M|   1|     0|     0|    1|[Men's 3000m Stee...|
# +----+-------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|              Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |   1|     BELENIUK Zhan|Ukraine|     M|   1|     0|     0|    1|[Men's Greco-Roma...|
# |   2|    LUZAN Liudmyla|Ukraine|     F|   0|     1|     1|    2|[Women's Canoe Si...|
# |   3|ROMANCHUK Mykhailo|Ukraine|     M|   0|     1|     1|    2|[Men's 800m Frees...|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+---------+------+----+------+------+-----+--------------------+
# |Rank|                Name|  Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+---------+------+----+------+------+-----+--------------------+
# |   1|       ROJAS Yulimar|Venezuela|     F|   1|     0|     0|    1|[Women's Triple J...|
# |   2|        DHERS Daniel|Venezuela|     M|   0|     1|     0|    1|        [Men's Park]|
# |   3|MAYORA PERNIA Jul...|Venezuela|     M|   0|     1|     0|    1|        [Men's 73kg]|
# +----+--------------------+---------+------+----+------+------+-----+--------------------+
#
# +----+---------------+-------+------+----+------+------+-----+--------------------+
# |Rank|           Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+---------------+-------+------+----+------+------+-----+--------------------+
# |   1|   ASHRAM Linoy| Israel|     F|   1|     0|     0|    1|[Individual All-A...|
# |   2|DOLGOPYAT Artem| Israel|     M|   1|     0|     0|    1|[Men's Floor Exer...|
# |   3|   BUTBUL Tohar| Israel|     M|   0|     0|     1|    1|        [Mixed Team]|
# +----+---------------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------+-----------+------+----+------+------+-----+--------------------+
# |Rank|        Name|    Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------+-----------+------+----+------+------+-----+--------------------+
# |   1|      AN San|South Korea|     F|   3|     0|     0|    3|[Women's Individu...|
# |   2| KIM Je Deok|South Korea|     M|   2|     0|     0|    2|[Men's Team, Mixe...|
# |   3|KIM Junghwan|South Korea|     M|   1|     0|     1|    2|[Men's Sabre Indi...|
# +----+------------+-----------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|     AGUIRRE Eduardo| Mexico|     M|   0|     0|     1|    1|          [Men Team]|
# |   2|       AGUIRRE Erick| Mexico|     M|   0|     0|     1|    1|          [Men Team]|
# |   3|AGUNDEZ GARCIA Ga...| Mexico|     F|   0|     0|     1|    1|[Women's Synchron...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |Rank|            Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |   1|   BEKAURI Lasha|Georgia|     M|   1|     0|     0|    1|        [Men -90 kg]|
# |   2|TALAKHADZE Lasha|Georgia|     M|   1|     0|     0|    1|      [Men's +109kg]|
# |   3|   KAJAIA Iakobi|Georgia|     M|   0|     1|     0|    1|[Men's Greco-Roma...|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
#
# +----+---------------+-------+------+----+------+------+-----+--------------------+
# |Rank|           Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+---------------+-------+------+----+------+------+-----+--------------------+
# |   1|  LEHIS Katrina|Estonia|     F|   1|     0|     1|    2|[Women's Épée Ind...|
# |   2|BELJAJEVA Julia|Estonia|     F|   1|     0|     0|    1| [Women's Épée Team]|
# |   3|  EMBRICH Irina|Estonia|     F|   1|     0|     0|    1| [Women's Épée Team]|
# +----+---------------+-------+------+----+------+------+-----+--------------------+
#
# +----+---------------+---------+------+----+------+------+-----+--------------------+
# |Rank|           Name|  Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+---------------+---------+------+----+------+------+-----+--------------------+
# |   1|  Greysia POLII|Indonesia|     F|   1|     0|     0|    1|[Women's Doubles ...|
# |   2|RAHAYU Apriyani|Indonesia|     F|   1|     0|     0|    1|[Women's Doubles ...|
# |   3|IRAWAN Eko Yuli|Indonesia|     M|   0|     1|     0|    1|        [Men's 61kg]|
# +----+---------------+---------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |Rank|                Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |   1|       MOLLAEI Saeid|Mongolia|     M|   0|     1|     0|    1|        [Men -81 kg]|
# |   2| BAT OCHIR Bolortuya|Mongolia|     F|   0|     0|     1|    1|[Women's Freestyl...|
# |   3|MUNKHBAT Urantsetseg|Mongolia|     F|   0|     0|     1|    1|      [Women -48 kg]|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
#
# +----+--------------+----------+------+----+------+------+-----+--------------------+
# |Rank|          Name|   Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------+----------+------+----+------+------+-----+--------------------+
# |   1|AGHAYEV Rafael|Azerbaijan|     M|   0|     1|     0|    1|[Men's Kumite -75kg]|
# |   2|   ALIYEV Haji|Azerbaijan|     M|   0|     1|     0|    1|[Men's Freestyle ...|
# |   3|ZARETSKA Iryna|Azerbaijan|     F|   0|     1|     0|    1|[Women's Kumite +...|
# +----+--------------+----------+------+----+------+------+-----+--------------------+
#
# +----+------------+-------+------+----+------+------+-----+------------+
# |Rank|        Name|Country|Gender|Gold|Silver|Bronze|Total|      Events|
# +----+------------+-------+------+----+------+------+-----+------------+
# |   1|JAMES Kirani|Grenada|     M|   0|     0|     1|    1|[Men's 400m]|
# +----+------------+-------+------+----+------+------+-----+------------+
#
# +----+-----------------+-------+------+----+------+------+-----+--------------------+
# |Rank|             Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-----------------+-------+------+----+------+------+-----+--------------------+
# |   1| ALEKSANYAN Artur|Armenia|     M|   0|     1|     0|    1|[Men's Greco-Roma...|
# |   2|MARTIROSYAN Simon|Armenia|     M|   0|     1|     0|    1|       [Men's 109kg]|
# |   3|BACHKOV Hovhannes|Armenia|     M|   0|     0|     1|    1|[Men's Light (57-...|
# +----+-----------------+-------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|      HAFNAOUI Ahmed|Tunisia|     M|   1|     0|     0|    1|[Men's 400m Frees...|
# |   2|JENDOUBI Mohamed ...|Tunisia|     M|   0|     1|     0|    1|         [Men -58kg]|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+---------+-------+------+----+------+------+-----+--------------+
# |Rank|     Name|Country|Gender|Gold|Silver|Bronze|Total|        Events|
# +----+---------+-------+------+----+------+------+-----+--------------+
# |   1|ASAAD Man|  Syria|     M|   0|     0|     1|    1|[Men's +109kg]|
# +----+---------+-------+------+----+------+------+-----+--------------+
#
# +----+------------+------------+------+----+------+------+-----+--------------------+
# |Rank|        Name|     Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------+------------+------+----+------+------+-----+--------------------+
# |   1|HAMEDI Tareg|Saudi Arabia|     M|   0|     1|     0|    1|[Men's Kumite +75kg]|
# +----+------------+------------+------+----+------+------+-----+--------------------+
#
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |Rank|            Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |   1|CHEPTEGEI Joshua| Uganda|     M|   1|     1|     0|    2|[Men's 5000m, Men...|
# |   2| CHEMUTAI Peruth| Uganda|     F|   1|     0|     0|    1|[Women's 3000m St...|
# |   3|   KIPLIMO Jacob| Uganda|     M|   0|     0|     1|    1|     [Men's 10,000m]|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
#
# +----+---------------+-------+------+----+------+------+-----+--------------+
# |Rank|           Name|Country|Gender|Gold|Silver|Bronze|Total|        Events|
# +----+---------------+-------+------+----+------+------+-----+--------------+
# |   1|MBOMA Christine|Namibia|     F|   0|     1|     0|    1|[Women's 200m]|
# +----+---------------+-------+------+----+------+------+-----+--------------+
#
# +----+--------------+-----------+------+----+------+------+-----+--------------------+
# |Rank|          Name|    Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------+-----------+------+----+------+------+-----+--------------------+
# |   1|BENCIC Belinda|Switzerland|     F|   1|     1|     0|    2|[Women's Singles,...|
# |   2| CHRISTEN Nina|Switzerland|     F|   1|     0|     1|    2| Air Rifle Wo...|
# |   3|  NEFF Jolanda|Switzerland|     F|   1|     0|     0|    1|[Women's Cross-co...|
# +----+--------------+-----------+------+----+------+------+-----+--------------------+
#
# +----+----------------+--------+------+----+------+------+-----+--------------------+
# |Rank|            Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+--------+------+----+------+------+-----+--------------------+
# |   1|  BAREGA Selemon|Ethiopia|     M|   1|     0|     0|    1|     [Men's 10,000m]|
# |   2|   GIRMA Lamecha|Ethiopia|     M|   0|     1|     0|    1|[Men's 3000m Stee...|
# |   3|GIDEY Letesenbet|Ethiopia|     F|   0|     0|     1|    1|   [Women's 10,000m]|
# +----+----------------+--------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|THOMPSON-HERAH El...|Jamaica|     F|   3|     0|     0|    3|[Women's 100m, Wo...|
# |   2|FRASER-PRYCE Shel...|Jamaica|     F|   1|     1|     0|    2|[Women's 100m, Wo...|
# |   3|    JACKSON Shericka|Jamaica|     F|   1|     0|     2|    3|[Women's 100m, Wo...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+---------------+-------+------+----+------+------+-----+----------+
# |Rank|           Name|Country|Gender|Gold|Silver|Bronze|Total|    Events|
# +----+---------------+-------+------+----+------+------+-----+----------+
# |   1|   CAVARS Agnis| Latvia|     M|   1|     0|     0|    1|[Men Team]|
# |   2| KRUMINS Edgars| Latvia|     M|   1|     0|     0|    1|[Men Team]|
# |   3|LASMANIS Karlis| Latvia|     M|   1|     0|     0|    1|[Men Team]|
# +----+---------------+-------+------+----+------+------+-----+----------+
#
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |Rank|            Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |   1|MACNEIL Margaret| Canada|     F|   1|     1|     1|    3|[Women's 100m But...|
# |   2| de GRASSE Andre| Canada|     M|   1|     0|     2|    3|[Men's 100m, Men'...|
# |   3|   BECKIE Janine| Canada|     F|   1|     0|     0|    1|        [Women Team]|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
#
# +----+----------------+----------+------+----+------+------+-----+--------------------+
# |Rank|            Name|   Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+----------+------+----+------+------+-----+--------------------+
# |   1|   DJURAEV Akbar|Uzbekistan|     M|   1|     0|     0|    1|       [Men's 109kg]|
# |   2|JALOLOV Bakhodir|Uzbekistan|     M|   1|     0|     0|    1|[Men's Super Heav...|
# |   3|RASHITOV Ulugbek|Uzbekistan|     M|   1|     0|     0|    1|         [Men -68kg]|
# +----+----------------+----------+------+----+------+------+-----+--------------------+
#
# +----+-----------------+---------------+------+----+------+------+-----+-----------+
# |Rank|             Name|        Country|Gender|Gold|Silver|Bronze|Total|     Events|
# +----+-----------------+---------------+------+----+------+------+-----+-----------+
# |   1|GEORGIEVSKI Dejan|North Macedonia|     M|   0|     1|     0|    1|[Men +80kg]|
# +----+-----------------+---------------+------+----+------+------+-----+-----------+
#
# +----+--------------------+----------+------+----+------+------+-----+--------------------+
# |Rank|                Name|   Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+----------+------+----+------+------+-----+--------------------+
# |   1|    MAKHMUDOV Akzhol|Kyrgyzstan|     M|   0|     1|     0|    1|[Men's Greco-Roma...|
# |   2|  TYNYBEKOVA Aisuluu|Kyrgyzstan|     F|   0|     1|     0|    1|[Women's Freestyl...|
# |   3|ZHUMANAZAROVA Meerim|Kyrgyzstan|     F|   0|     0|     1|    1|[Women's Freestyl...|
# +----+--------------------+----------+------+----+------+------+-----+--------------------+
#
# +----+------------------+--------------+------+----+------+------+-----+--------------------+
# |Rank|              Name|       Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------------+--------------+------+----+------+------+-----+--------------------+
# |   1|KREJCIKOVA Barbora|Czech Republic|     F|   1|     0|     0|    1|[Women's Doubles ...|
# |   2|     KRPALEK Lukas|Czech Republic|     M|   1|     0|     0|    1|       [Men +100 kg]|
# |   3|       LIPTAK Jiri|Czech Republic|     M|   1|     0|     0|    1|          [Trap Men]|
# +----+------------------+--------------+------+----+------+------+-----+--------------------+
#
# +----+--------------+-------+------+----+------+------+-----+--------------------+
# |Rank|          Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------+-------+------+----+------+------+-----+--------------------+
# |   1|ANDRADE Rebeca| Brazil|     F|   1|     1|     0|    2|[Women's All-Arou...|
# |   2|         ABNER| Brazil|     M|   1|     0|     0|    1|          [Men Team]|
# |   3|    ALVES Dani| Brazil|     M|   1|     0|     0|    1|          [Men Team]|
# +----+--------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-----------------+-------+------+----+------+------+-----+------------------+
# |Rank|             Name|Country|Gender|Gold|Silver|Bronze|Total|            Events|
# +----+-----------------+-------+------+----+------+------+-----+------------------+
# |   1|JEPCHIRCHIR Peres|  Kenya|     F|   1|     0|     0|    1|[Women's Marathon]|
# |   2|   KIPCHOGE Eliud|  Kenya|     M|   1|     0|     0|    1|  [Men's Marathon]|
# |   3|   KIPYEGON Faith|  Kenya|     F|   1|     0|     0|    1|   [Women's 1500m]|
# +----+-----------------+-------+------+----+------+------+-----+------------------+
#
# +----+---------------+--------+------+----+------+------+-----+--------------------+
# |Rank|           Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+---------------+--------+------+----+------+------+-----+--------------------+
# |   1| GARNBRET Janja|Slovenia|     F|   1|     0|     0|    1|  [Women's Combined]|
# |   2|  ROGLIC Primoz|Slovenia|     M|   1|     0|     0|    1|[Men's Individual...|
# |   3|SAVSEK Benjamin|Slovenia|     M|   1|     0|     0|    1|       [Men's Canoe]|
# +----+---------------+--------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+------------------+------+----+------+------+-----+--------------------+
# |Rank|                Name|           Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+------------------+------+----+------+------+-----+--------------------+
# |   1|   PAULINO Marileidy|Dominican Republic|     F|   0|     2|     0|    2|[Women's 400m, 4 ...|
# |   2|BONNAT MICHEL Zac...|Dominican Republic|     M|   0|     1|     0|    1|        [Men's 81kg]|
# |   3|  FELIZ Lidio Andres|Dominican Republic|     M|   0|     1|     0|    1|[4 x 400m Relay M...|
# +----+--------------------+------------------+------+----+------+------+-----+--------------------+
#
# +----+---------------+-------+------+----+------+------+-----+--------------------+
# |Rank|           Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+---------------+-------+------+----+------+------+-----+--------------------+
# |   1|HASHIMOTO Daiki|  Japan|     M|   2|     1|     0|    3|[Men's All-Around...|
# |   2|     OHASHI Yui|  Japan|     F|   2|     0|     0|    2|[Women's 200m Ind...|
# |   3|       ITO Mima|  Japan|     F|   1|     1|     1|    3|[Women's Singles,...|
# +----+---------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-------------+--------+------+----+------+------+-----+--------------------+
# |Rank|         Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-------------+--------+------+----+------+------+-----+--------------------+
# |   1|MAKWALA Isaac|Botswana|     M|   0|     0|     1|    1|[Men's 4 x 400m R...|
# |   2| NDORI Bayapo|Botswana|     M|   0|     0|     1|    1|[Men's 4 x 400m R...|
# |   3| NGOZI Zibane|Botswana|     M|   0|     0|     1|    1|[Men's 4 x 400m R...|
# +----+-------------+--------+------+----+------+------+-----+--------------------+
#
# +----+-----------------+-----------+------+----+------+------+-----+--------------------+
# |Rank|             Name|    Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-----------------+-----------+------+----+------+------+-----+--------------------+
# |   1|  CARRINGTON Lisa|New Zealand|     F|   3|     0|     0|    3|[Women's Kayak Si...|
# |   2|     GOWLER Kerri|New Zealand|     F|   1|     1|     0|    2|[Women's Pair Tea...|
# |   3|PRENDERGAST Grace|New Zealand|     F|   1|     1|     0|    2|[Women's Pair Tea...|
# +----+-----------------+-----------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|                Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
# |   1|  BAUMGART-WITAN Iga| Poland|     F|   1|     1|     0|    2|[Women's 4 x 400m...|
# |   2|HOLUB-KOWALIK Mal...| Poland|     F|   1|     1|     0|    2|[Women's 4 x 400m...|
# |   3|   KACZMAREK Natalia| Poland|     F|   1|     1|     0|    2|[Women's 4 x 400m...|
# +----+--------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+---------------+--------+------+----+------+------+-----+--------------------+
# |Rank|           Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+---------------+--------+------+----+------+------+-----+--------------------+
# |   1| PICHARDO Pedro|Portugal|     M|   1|     0|     0|    1| [Men's Triple Jump]|
# |   2|MAMONA Patricia|Portugal|     F|   0|     1|     0|    1|[Women's Triple J...|
# |   3|  FONSECA Jorge|Portugal|     M|   0|     0|     1|    1|       [Men -100 kg]|
# +----+---------------+--------+------+----+------+------+-----+--------------------+
#
# +----+--------------+---------+------+----+------+------+-----+--------------------+
# |Rank|          Name|  Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------+---------+------+----+------+------+-----+--------------------+
# |   1|   McKEON Emma|Australia|     F|   4|     0|     3|    7|[Women's 50m Free...|
# |   2|McKEOWN Kaylee|Australia|     F|   3|     0|     1|    4|[Women's 100m Bac...|
# |   3|TITMUS Ariarne|Australia|     F|   2|     1|     1|    4|[Women's 200m Fre...|
# +----+--------------+---------+------+----+------+------+-----+--------------------+
#
# +----+--------------+-------+------+----+------+------+-----+--------------------+
# |Rank|          Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------+-------+------+----+------+------+-----+--------------------+
# |   1| BODNAR Ancuta|Romania|     F|   1|     0|     0|    1|[Women's Double S...|
# |   2|  RADIS Simona|Romania|     F|   1|     0|     0|    1|[Women's Double S...|
# |   3|BERARIU Stefan|Romania|     M|   0|     1|     0|    1|   [Men's Four Team]|
# +----+--------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-----------------+--------+------+----+------+------+-----+--------------------+
# |Rank|             Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-----------------+--------+------+----+------+------+-----+--------------------+
# |   1|  DYANKOVA Simona|Bulgaria|     F|   1|     0|     0|    1|[Group All-Around...|
# |   2|    GORANOVA Ivet|Bulgaria|     F|   1|     0|     0|    1|[Women's Kumite -...|
# |   3|KIRYAKOVA Stefani|Bulgaria|     F|   1|     0|     0|    1|[Group All-Around...|
# +----+-----------------+--------+------+----+------+------+-----+--------------------+
#
# +----+-------------------+-------+------+----+------+------+-----+-------------------+
# |Rank|               Name|Country|Gender|Gold|Silver|Bronze|Total|             Events|
# +----+-------------------+-------+------+----+------+------+-----+-------------------+
# |   1|   KIESENHOFER Anna|Austria|     F|   1|     0|     0|    1|[Women's Road Race]|
# |   2|  POLLERES Michaela|Austria|     F|   0|     1|     0|    1|     [Women -70 kg]|
# |   3|BORCHASHVILI Shamil|Austria|     M|   0|     0|     1|    1|       [Men -81 kg]|
# +----+-------------------+-------+------+----+------+------+-----+-------------------+
#
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |Rank|            Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
# |   1|ABDELAZIZ Feryal|  Egypt|     F|   1|     0|     0|    1|[Women's Kumite +...|
# |   2|   ELGENDY Ahmed|  Egypt|     M|   0|     1|     0|    1|  [Men's Individual]|
# |   3|      EISSA Seif|  Egypt|     M|   0|     0|     1|    1|         [Men -80kg]|
# +----+----------------+-------+------+----+------+------+-----+--------------------+
#
# +----+-----------------+----------+------+----+------+------+-----+--------------------+
# |Rank|             Name|   Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-----------------+----------+------+----+------+------+-----+--------------------+
# |   1|ASSADILOV Darkhan|Kazakhstan|     M|   0|     0|     1|    1|[Men's Kumite -67kg]|
# |   2| BERULTSEVA Sofya|Kazakhstan|     F|   0|     0|     1|    1|[Women's Kumite +...|
# |   3| BIBOSSINOV Saken|Kazakhstan|     M|   0|     0|     1|    1|[Men's Fly (48-52...|
# +----+-----------------+----------+------+----+------+------+-----+--------------------+
#
# +----+---------------+-------+------+----+------+------+-----+----------+
# |Rank|           Name|Country|Gender|Gold|Silver|Bronze|Total|    Events|
# +----+---------------+-------+------+----+------+------+-----+----------+
# |   1|  ALEKSIC Milan| Serbia|     M|   1|     0|     0|    1|[Men Team]|
# |   2| DEDOVIC Nikola| Serbia|     M|   1|     0|     0|    1|[Men Team]|
# |   3|FILIPOVIC Filip| Serbia|     M|   1|     0|     0|    1|[Men Team]|
# +----+---------------+-------+------+----+------+------+-----+----------+
#
# +----+-------------------+------------+------+----+------+------+-----+--------------------+
# |Rank|               Name|     Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-------------------+------------+------+----+------+------+-----+--------------------+
# |   1|SCHOENMAKER Tatjana|South Africa|     F|   1|     1|     0|    2|[Women's 100m Bre...|
# |   2|   BUITENDAG Bianca|South Africa|     F|   0|     1|     0|    1|             [Women]|
# +----+-------------------+------------+------+----+------+------+-----+--------------------+
#
# +----+--------------------+------------+------+----+------+------+-----+-------------------+
# |Rank|                Name|     Country|Gender|Gold|Silver|Bronze|Total|             Events|
# +----+--------------------+------------+------+----+------+------+-----+-------------------+
# |   1|ZANGO Hugues Fabrice|Burkina Faso|     M|   0|     0|     1|    1|[Men's Triple Jump]|
# +----+--------------------+------------+------+----+------+------+-----+-------------------+
#
# +----+-----------+-------+------+----+------+------+-----+--------------------+
# |Rank|       Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-----------+-------+------+----+------+------+-----+--------------------+
# |   1|DUFFY Flora|Bermuda|     F|   1|     0|     0|    1|[Women's Individual]|
# +----+-----------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------------+-------+------+----+------+------+-----+-----------------+
# |Rank|              Name|Country|Gender|Gold|Silver|Bronze|Total|           Events|
# +----+------------------+-------+------+----+------+------+-----+-----------------+
# |   1|GEZAHEGNE Kalkidan|Bahrain|     F|   0|     1|     0|    1|[Women's 10,000m]|
# +----+------------------+-------+------+----+------+------+-----+-----------------+
#
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |Rank|                Name| Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
# |   1|ARENAS Sandra Lorena|Colombia|     F|   0|     1|     0|    1|[Women's 20km Rac...|
# |   2|MOSQUERA LOZANO L...|Colombia|     M|   0|     1|     0|    1|        [Men's 67kg]|
# |   3|       PAJON Mariana|Colombia|     F|   0|     1|     0|    1|             [Women]|
# +----+--------------------+--------+------+----+------+------+-----+--------------------+
#
# +----+-------------+-------+------+----+------+------+-----+--------------------+
# |Rank|         Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+-------------+-------+------+----+------+------+-----+--------------------+
# |   1|CSIPES Tamara|Hungary|     F|   1|     1|     0|    2|[Women's Kayak Si...|
# |   2|MILAK Kristof|Hungary|     M|   1|     1|     0|    2|[Men's 100m Butte...|
# |   3| BODONYI Dora|Hungary|     F|   1|     0|     1|    2|[Women's Kayak Do...|
# +----+-------------+-------+------+----+------+------+-----+--------------------+
#
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |Rank|              Name|Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
# |   1|TARNOVSCHI Serghei|Moldova|     M|   0|     0|     1|    1|[Men's Canoe Sing...|
# +----+------------------+-------+------+----+------+------+-----+--------------------+
#
# +----+----------------+-----------+------+----+------+------+-----+--------------------+
# |Rank|            Name|    Country|Gender|Gold|Silver|Bronze|Total|              Events|
# +----+----------------+-----------+------+----+------+------+-----+--------------------+
# |   1|    HASSAN Sifan|Netherlands|     F|   2|     0|     1|    3|[Women's 1500m, W...|
# |   2|LAVREYSEN Harrie|Netherlands|     M|   2|     0|     1|    3|[Men's Team Sprin...|
# |   3|HOOGLAND Jeffrey|Netherlands|     M|   1|     1|     0|    2|[Men's Team Sprin...|
# +----+----------------+-----------+------+----+------+------+-----+--------------------+

# %% [markdown]
# # Advance Code

# %%
# Import necessary Spark libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import count, when, col, collect_list, max
from pyspark.sql.window import Window
import pyspark.sql.functions as F

# Create a Spark session
spark = SparkSession.builder.appName('project').getOrCreate()

# Load the dataset
df = spark.read.option('inferschema', 'true').option('header', 'true').csv('/content/2020_olympics_data.csv')

# Function to calculate medal counts for a given group column
def result(df, group_col, partition_col=None, rank_limit=None):
    # Define the aggregation columns for medal counts
    agg_columns = [
        count(when(df['Medal'] == 'Gold', True)).alias('Gold'),
        count(when(df['Medal'] == 'Silver', True)).alias('Silver'),
        count(when(df['Medal'] == 'Bronze', True)).alias('Bronze'),
        count(when(df['Medal'] != 'None', True)).alias('Total'),
    ]

    # Create a window specification for ranking
    window_spec = Window.partitionBy(partition_col).orderBy(
        col("Gold").desc(), col("Silver").desc(), col("Bronze").desc(), col("Total").desc()
    ) if partition_col else Window.orderBy(
        col("Gold").desc(), col("Silver").desc(), col("Bronze").desc(), col("Total").desc()
    )

    # If both group_col and partition_col are provided, aggregate by both columns
    if group_col and partition_col:
        result_df = df.groupBy(partition_col, group_col).agg(*agg_columns).filter(col('Total') > 0)
    # If only group_col is provided, aggregate by that column
    elif group_col:
        result_df = df.groupBy(group_col).agg(*agg_columns).filter(col('Total') > 0)

    # If the group column is "Name," also collect the list of events
    if group_col == "Name":
        events_df = df.filter(df['Medal'] != 'None').groupBy(group_col).agg(
            collect_list("Event").alias('Event')
        )
        result_df = result_df.join(events_df, [group_col], "left")

    # Calculate the rank for each group
    result_df = result_df.withColumn("Rank", F.row_number().over(window_spec))

    # If rank_limit is provided, filter rows by rank
    if rank_limit:
        result_df = result_df.filter(col('Rank') <= rank_limit)

    # Show the result
    result_df.show()
    return result_df

# Perform different analyses using the defined functions
# 1. Medal Count for countries
result_df1=result(df, 'Country')

# 2. Medal Count of Top Countries in Each Sport
result_df2=result(df, 'Country', 'Sport')

# 3. Medal Count of Top Sport Performances in Each Country
result_df3=result(df, 'Sport', 'Country')

# 4. Top  Athletes
result_df4=result(df, 'Name')

# 5. Details of Top Athletes in Each Country along with countries with no medals
result_df5=result(df, 'Name', 'Country')
# Out:
# +-------------+----+------+------+-----+----+
# |      Country|Gold|Silver|Bronze|Total|Rank|
# +-------------+----+------+------+-----+----+
# |United States| 113|   110|    75|  298|   1|
# |        Japan|  68|    41|    22|  131|   2|
# |       France|  65|    42|    34|  141|   3|
# |        China|  59|    49|    33|  141|   4|
# |       Russia|  41|    80|    28|  149|   5|
# |Great Britain|  41|    43|    57|  141|   6|
# |    Australia|  36|    28|    67|  131|   7|
# |       Canada|  36|    11|    38|   85|   8|
# |  Netherlands|  33|    22|    17|   72|   9|
# |  New Zealand|  29|    28|     8|   65|  10|
# |       Brazil|  29|    17|     9|   55|  11|
# |        Italy|  22|    17|    37|   76|  12|
# |      Germany|  21|    26|    34|   81|  13|
# |      Belgium|  20|     1|     6|   27|  14|
# |       Serbia|  15|     1|    19|   35|  15|
# |       Poland|  14|    14|     8|   36|  16|
# |  South Korea|  14|     7|    17|   38|  17|
# |         Fiji|  13|     0|    13|   26|  18|
# |      Hungary|   9|     7|    35|   51|  19|
# |      Jamaica|   9|     1|    11|   21|  20|
# +-------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +-------------------+--------------+----+------+------+-----+----+
# |              Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +-------------------+--------------+----+------+------+-----+----+
# |     3x3 Basketball|        Latvia|   4|     0|     0|    4|   1|
# |     3x3 Basketball| United States|   4|     0|     0|    4|   2|
# |     3x3 Basketball|        Russia|   0|     8|     0|    8|   3|
# |     3x3 Basketball|         China|   0|     0|     4|    4|   4|
# |     3x3 Basketball|        Serbia|   0|     0|     4|    4|   5|
# |            Archery|   South Korea|   9|     0|     0|    9|   1|
# |            Archery|        Turkey|   1|     0|     0|    1|   2|
# |            Archery|        Russia|   0|     4|     0|    4|   3|
# |            Archery|Chinese Taipei|   0|     3|     0|    3|   4|
# |            Archery|   Netherlands|   0|     2|     0|    2|   5|
# |            Archery|         Italy|   0|     1|     1|    2|   6|
# |            Archery|         Japan|   0|     0|     4|    4|   7|
# |            Archery|       Germany|   0|     0|     3|    3|   8|
# |            Archery|        Mexico|   0|     0|     2|    2|   9|
# |Artistic Gymnastics|        Russia|   8|     2|     4|   14|   1|
# |Artistic Gymnastics|         China|   3|     3|     5|   11|   2|
# |Artistic Gymnastics| United States|   2|     5|     2|    9|   3|
# |Artistic Gymnastics|         Japan|   2|     4|     2|    8|   4|
# |Artistic Gymnastics|        Brazil|   1|     1|     0|    2|   5|
# |Artistic Gymnastics| Great Britain|   1|     0|     4|    5|   6|
# +-------------------+--------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +---------+--------------------+----+------+------+-----+----+
# |  Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +---------+--------------------+----+------+------+-----+----+
# |Argentina|              Hockey|   0|    18|     0|   18|   1|
# |Argentina|        Rugby Sevens|   0|     0|    13|   13|   2|
# |Argentina|          Volleyball|   0|     0|    12|   12|   3|
# |  Armenia|           Wrestling|   0|     1|     0|    1|   1|
# |  Armenia|       Weightlifting|   0|     1|     0|    1|   2|
# |  Armenia| Artistic Gymnastics|   0|     0|     1|    1|   3|
# |  Armenia|              Boxing|   0|     0|     1|    1|   4|
# |Australia|            Swimming|  20|     3|    30|   53|   1|
# |Australia|              Rowing|   8|     0|     8|   16|   2|
# |Australia|             Sailing|   3|     0|     0|    3|   3|
# |Australia|        Canoe Sprint|   2|     0|     0|    2|   4|
# |Australia|        Canoe Slalom|   1|     0|     1|    2|   5|
# |Australia|       Skateboarding|   1|     0|     0|    1|   6|
# |Australia|Cycling BMX Frees...|   1|     0|     0|    1|   7|
# |Australia|              Hockey|   0|    18|     0|   18|   8|
# |Australia|          Equestrian|   0|     4|     1|    5|   9|
# |Australia|    Beach Volleyball|   0|     2|     0|    2|  10|
# |Australia|           Athletics|   0|     1|     2|    3|  11|
# |Australia|          Basketball|   0|     0|    12|   12|  12|
# |Australia|       Cycling Track|   0|     0|     6|    6|  13|
# +---------+--------------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +--------------------+----+------+------+-----+--------------------+----+
# |                Name|Gold|Silver|Bronze|Total|               Event|Rank|
# +--------------------+----+------+------+-----+--------------------+----+
# |      DRESSEL Caeleb|   5|     0|     0|    5|[Men's 50m Freest...|   1|
# |         McKEON Emma|   4|     0|     3|    7|[Women's 50m Free...|   2|
# |      McKEOWN Kaylee|   3|     0|     1|    4|[Women's 100m Bac...|   3|
# |     CARRINGTON Lisa|   3|     0|     0|    3|[Women's Kayak Si...|   4|
# |              AN San|   3|     0|     0|    3|[Women's Individu...|   5|
# |THOMPSON-HERAH El...|   3|     0|     0|    3|[Women's 100m, Wo...|   6|
# |         ZHANG Yufei|   2|     2|     0|    4|[Women's 100m But...|   7|
# |    LEDECKY Kathleen|   2|     2|     0|    4|[Women's 400m Fre...|   8|
# |      TITMUS Ariarne|   2|     1|     1|    4|[Women's 200m Fre...|   9|
# |BATSARASHKINA Vit...|   2|     1|     0|    3| Air Pistol W...|  10|
# |     HASHIMOTO Daiki|   2|     1|     0|    3|[Men's All-Around...|  11|
# |        RYLOV Evgeny|   2|     1|     0|    3|[Men's 100m Backs...|  12|
# |           GUY James|   2|     1|     0|    3|[Men's 4 x 200m F...|  13|
# |          PEATY Adam|   2|     1|     0|    3|[Men's 100m Breas...|  14|
# |        HASSAN Sifan|   2|     0|     1|    3|[Women's 1500m, W...|  15|
# |       CAMPBELL Cate|   2|     0|     1|    3|[Women's 100m Fre...|  16|
# |    LAVREYSEN Harrie|   2|     0|     1|    3|[Men's Team Sprin...|  17|
# |  O'CALLAGHAN Mollie|   2|     0|     1|    3|[Women's 4 x 100m...|  18|
# |           YANG Qian|   2|     0|     0|    2| Air Rifle Wo...|  19|
# |   McLAUGHLIN Sydney|   2|     0|     0|    2|[Women's 400m Hur...|  20|
# +--------------------+----+------+------+-----+--------------------+----+
# only showing top 20 rows
#
# +--------------------+---------+----+------+------+-----+------------+----+
# |                Name|  Country|Gold|Silver|Bronze|Total|       Event|Rank|
# +--------------------+---------+----+------+------+-----+------------+----+
# |TRINCHINETTI Euge...|Argentina|   0|     1|     0|    1|[Women Team]|   1|
# |ALBERTARRIO Agustina|Argentina|   0|     1|     0|    1|[Women Team]|   2|
# |BARRIONUEVO Maria...|Argentina|   0|     1|     0|    1|[Women Team]|   3|
# | GRANATTO Maria Jose|Argentina|   0|     1|     0|    1|[Women Team]|   4|
# |RAPOSO RUIZ de lo...|Argentina|   0|     1|     0|    1|[Women Team]|   5|
# |       MACCARI Sofia|Argentina|   0|     1|     0|    1|[Women Team]|   6|
# |  GORZELANY Agustina|Argentina|   0|     1|     0|    1|[Women Team]|   7|
# |COSTA BIONDI Vale...|Argentina|   0|     1|     0|    1|[Women Team]|   8|
# |FORCHERIO Maria E...|Argentina|   0|     1|     0|    1|[Women Team]|   9|
# |     ALONSO Agostina|Argentina|   0|     1|     0|    1|[Women Team]|  10|
# |GRANATTO Maria Vi...|Argentina|   0|     1|     0|    1|[Women Team]|  11|
# |    JANKUNAS Julieta|Argentina|   0|     1|     0|    1|[Women Team]|  12|
# |SANCHEZ MOCCIA Rocio|Argentina|   0|     1|     0|    1|[Women Team]|  13|
# |     TOCCALINO Sofia|Argentina|   0|     1|     0|    1|[Women Team]|  14|
# |     RETEGUI Micaela|Argentina|   0|     1|     0|    1|[Women Team]|  15|
# |   SUCCI Maria Belen|Argentina|   0|     1|     0|    1|[Women Team]|  16|
# |SAUZE VALDEZ Vict...|Argentina|   0|     1|     0|    1|[Women Team]|  17|
# |      MERINO Delfina|Argentina|   0|     1|     0|    1|[Women Team]|  18|
# |    PEREYRA Federico|Argentina|   0|     0|     1|    1|  [Men Team]|  19|
# |    de CECCO Luciano|Argentina|   0|     0|     1|    1|  [Men Team]|  20|
# +--------------------+---------+----+------+------+-----+------------+----+
# only showing top 20 rows

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-e5ed3973f440> in <cell line: 1>()
# ----> 1 result_df1.show()
#
# AttributeError: 'NoneType' object has no attribute 'show'

# %% [markdown]
# import pandas as pd
#
# # Define a function to export multiple DataFrames to an Excel file with different worksheets
# def export_to_excel(dataframes, filename):
#     with pd.ExcelWriter(filename, engine='xlsxwriter') as writer:
#         for sheet_name, df in dataframes.items():
#             df.to_excel(writer, sheet_name=sheet_name, index=False)
#
# # Example usage:
# # Create a dictionary with sheet names as keys and DataFrames as values
# dataframes = {
#     'MedalCountsByCountry': result_df1,  # Replace with your actual DataFrames
#     'MedalCountsBySport': result_df2,
#     'Top10CountriesInEachSport': result_df3,
#     'Top10SportPerformanceInEachCountry': result_df4,
#     'Top10Athletes': result_df5
# }
#
# # Specify the Excel file name
# excel_filename = 'olympic_report.xlsx'
#
# # Export the DataFrames to the Excel file with different worksheets
# export_to_excel(dataframes, excel_filename)

# %%
# !pip install XlsxWriter

# %%
import pandas as pd
import xlsxwriter

# Define a function to export multiple DataFrames to an Excel file with different worksheets
def export_to_excel(dataframes, filename):
    with pd.ExcelWriter(filename, engine='xlsxwriter') as writer:
        for sheet_name, df in dataframes.items():
            df.to_excel(writer, sheet_name=sheet_name, index=False)

pandas_df1 = result_df1.toPandas()
print(pandas_df1)
pandas_df2 = result_df2.toPandas()
pandas_df3 = result_df3.toPandas()
pandas_df4 = result_df4.toPandas()
pandas_df5 = result_df5.toPandas()

# Example usage:
# Create a dictionary with sheet names as keys and DataFrames as values
dataframes = {
    'MedalCountsByCountry': pandas_df1,
    'TopCountriesInSport': pandas_df2,  # Modified sheet name
    'TopSportsInEachCountry': pandas_df3,  # Modified sheet name
    'Top10Athletes': pandas_df4,
    'TopAthletesInEachCountry': pandas_df5  # Modified sheet name
}

# Specify the Excel file name
excel_filename = '/content/olympic_report.xlsx'

# Export the DataFrames to the Excel file with different worksheets
export_to_excel(dataframes, excel_filename)
# Out:
# Requirement already satisfied: XlsxWriter in /usr/local/lib/python3.10/dist-packages (3.1.2)
#           Country  Gold  Silver  Bronze  Total  Rank
# 0   United States   113     110      75    298     1
# 1           Japan    68      41      22    131     2
# 2          France    65      42      34    141     3
# 3           China    59      49      33    141     4
# 4          Russia    41      80      28    149     5
# ..            ...   ...     ...     ...    ...   ...
# 88         Kuwait     0       0       1      1    89
# 89        Grenada     0       0       1      1    90
# 90          Syria     0       0       1      1    91
# 91   Burkina Faso     0       0       1      1    92
# 92        Moldova     0       0       1      1    93
#
# [93 rows x 6 columns]

# %%
# Example usage:
# result_df(df, group_col, partition_col, rank_limit)
result_df(df, 'Country')  # Medal Count for countries
result_df(df, 'Country', 'Sport', rank_limit=10)  # Medal Count of Top 10 Countries in Each Sport
result_df(df, 'Sport', 'Country', rank_limit=10)  # Medal Count of Top 10 Sport Performance in Each Country
result_df(df, 'Name', rank_limit=10)  # Top 10 Athletes
result_df(df, 'Name', 'Country', rank_limit=3)  # Details of 3 Athletes in Each Country
# Out:
# +-------------+----+------+------+-----+----+
# |      Country|Gold|Silver|Bronze|Total|Rank|
# +-------------+----+------+------+-----+----+
# |United States| 113|   110|    75|  298|   1|
# |        Japan|  68|    41|    22|  131|   2|
# |       France|  65|    42|    34|  141|   3|
# |        China|  59|    49|    33|  141|   4|
# |       Russia|  41|    80|    28|  149|   5|
# |Great Britain|  41|    43|    57|  141|   6|
# |    Australia|  36|    28|    67|  131|   7|
# |       Canada|  36|    11|    38|   85|   8|
# |  Netherlands|  33|    22|    17|   72|   9|
# |  New Zealand|  29|    28|     8|   65|  10|
# |       Brazil|  29|    17|     9|   55|  11|
# |        Italy|  22|    17|    37|   76|  12|
# |      Germany|  21|    26|    34|   81|  13|
# |      Belgium|  20|     1|     6|   27|  14|
# |       Serbia|  15|     1|    19|   35|  15|
# |       Poland|  14|    14|     8|   36|  16|
# |  South Korea|  14|     7|    17|   38|  17|
# |         Fiji|  13|     0|    13|   26|  18|
# |      Hungary|   9|     7|    35|   51|  19|
# |      Jamaica|   9|     1|    11|   21|  20|
# +-------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +-------------------+--------------+----+------+------+-----+----+
# |              Sport|       Country|Gold|Silver|Bronze|Total|Rank|
# +-------------------+--------------+----+------+------+-----+----+
# |     3x3 Basketball|        Latvia|   4|     0|     0|    4|   1|
# |     3x3 Basketball| United States|   4|     0|     0|    4|   2|
# |     3x3 Basketball|        Russia|   0|     8|     0|    8|   3|
# |     3x3 Basketball|         China|   0|     0|     4|    4|   4|
# |     3x3 Basketball|        Serbia|   0|     0|     4|    4|   5|
# |            Archery|   South Korea|   9|     0|     0|    9|   1|
# |            Archery|        Turkey|   1|     0|     0|    1|   2|
# |            Archery|        Russia|   0|     4|     0|    4|   3|
# |            Archery|Chinese Taipei|   0|     3|     0|    3|   4|
# |            Archery|   Netherlands|   0|     2|     0|    2|   5|
# |            Archery|         Italy|   0|     1|     1|    2|   6|
# |            Archery|         Japan|   0|     0|     4|    4|   7|
# |            Archery|       Germany|   0|     0|     3|    3|   8|
# |            Archery|        Mexico|   0|     0|     2|    2|   9|
# |Artistic Gymnastics|        Russia|   8|     2|     4|   14|   1|
# |Artistic Gymnastics|         China|   3|     3|     5|   11|   2|
# |Artistic Gymnastics| United States|   2|     5|     2|    9|   3|
# |Artistic Gymnastics|         Japan|   2|     4|     2|    8|   4|
# |Artistic Gymnastics|        Brazil|   1|     1|     0|    2|   5|
# |Artistic Gymnastics| Great Britain|   1|     0|     4|    5|   6|
# +-------------------+--------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +---------+--------------------+----+------+------+-----+----+
# |  Country|               Sport|Gold|Silver|Bronze|Total|Rank|
# +---------+--------------------+----+------+------+-----+----+
# |Argentina|              Hockey|   0|    18|     0|   18|   1|
# |Argentina|        Rugby Sevens|   0|     0|    13|   13|   2|
# |Argentina|          Volleyball|   0|     0|    12|   12|   3|
# |  Armenia|           Wrestling|   0|     1|     0|    1|   1|
# |  Armenia|       Weightlifting|   0|     1|     0|    1|   2|
# |  Armenia| Artistic Gymnastics|   0|     0|     1|    1|   3|
# |  Armenia|              Boxing|   0|     0|     1|    1|   4|
# |Australia|            Swimming|  20|     3|    30|   53|   1|
# |Australia|              Rowing|   8|     0|     8|   16|   2|
# |Australia|             Sailing|   3|     0|     0|    3|   3|
# |Australia|        Canoe Sprint|   2|     0|     0|    2|   4|
# |Australia|        Canoe Slalom|   1|     0|     1|    2|   5|
# |Australia|       Skateboarding|   1|     0|     0|    1|   6|
# |Australia|Cycling BMX Frees...|   1|     0|     0|    1|   7|
# |Australia|              Hockey|   0|    18|     0|   18|   8|
# |Australia|          Equestrian|   0|     4|     1|    5|   9|
# |Australia|    Beach Volleyball|   0|     2|     0|    2|  10|
# |  Austria|        Cycling Road|   1|     0|     0|    1|   1|
# |  Austria|                Judo|   0|     1|     1|    2|   2|
# |  Austria|           Athletics|   0|     0|     1|    1|   3|
# +---------+--------------------+----+------+------+-----+----+
# only showing top 20 rows
#
# +--------------------+----+------+------+-----+--------------------+----+
# |                Name|Gold|Silver|Bronze|Total|               Event|Rank|
# +--------------------+----+------+------+-----+--------------------+----+
# |      DRESSEL Caeleb|   5|     0|     0|    5|[Men's 50m Freest...|   1|
# |         McKEON Emma|   4|     0|     3|    7|[Women's 50m Free...|   2|
# |      McKEOWN Kaylee|   3|     0|     1|    4|[Women's 100m Bac...|   3|
# |     CARRINGTON Lisa|   3|     0|     0|    3|[Women's Kayak Si...|   4|
# |              AN San|   3|     0|     0|    3|[Women's Individu...|   5|
# |THOMPSON-HERAH El...|   3|     0|     0|    3|[Women's 100m, Wo...|   6|
# |         ZHANG Yufei|   2|     2|     0|    4|[Women's 100m But...|   7|
# |    LEDECKY Kathleen|   2|     2|     0|    4|[Women's 400m Fre...|   8|
# |      TITMUS Ariarne|   2|     1|     1|    4|[Women's 200m Fre...|   9|
# |BATSARASHKINA Vit...|   2|     1|     0|    3| Air Pistol W...|  10|
# +--------------------+----+------+------+-----+--------------------+----+
#
# +--------------------+----------+----+------+------+-----+--------------------+----+
# |                Name|   Country|Gold|Silver|Bronze|Total|               Event|Rank|
# +--------------------+----------+----+------+------+-----+--------------------+----+
# |TRINCHINETTI Euge...| Argentina|   0|     1|     0|    1|        [Women Team]|   1|
# |ALBERTARRIO Agustina| Argentina|   0|     1|     0|    1|        [Women Team]|   2|
# |BARRIONUEVO Maria...| Argentina|   0|     1|     0|    1|        [Women Team]|   3|
# |   MARTIROSYAN Simon|   Armenia|   0|     1|     0|    1|       [Men's 109kg]|   1|
# |    ALEKSANYAN Artur|   Armenia|   0|     1|     0|    1|[Men's Greco-Roma...|   2|
# |   BACHKOV Hovhannes|   Armenia|   0|     0|     1|    1|[Men's Light (57-...|   3|
# |         McKEON Emma| Australia|   4|     0|     3|    7|[Women's 50m Free...|   1|
# |      McKEOWN Kaylee| Australia|   3|     0|     1|    4|[Women's 100m Bac...|   2|
# |      TITMUS Ariarne| Australia|   2|     1|     1|    4|[Women's 200m Fre...|   3|
# |    KIESENHOFER Anna|   Austria|   1|     0|     0|    1| [Women's Road Race]|   1|
# |   POLLERES Michaela|   Austria|   0|     1|     0|    1|      [Women -70 kg]|   2|
# |    LOBNIG Magdalena|   Austria|   0|     0|     1|    1|[Women's Single S...|   3|
# |      ZARETSKA Iryna|Azerbaijan|   0|     1|     0|    1|[Women's Kumite +...|   1|
# |      AGHAYEV Rafael|Azerbaijan|   0|     1|     0|    1|[Men's Kumite -75kg]|   2|
# |         ALIYEV Haji|Azerbaijan|   0|     1|     0|    1|[Men's Freestyle ...|   3|
# | MILLER-UIBO Shaunae|   Bahamas|   1|     0|     0|    1|      [Women's 400m]|   1|
# |     GARDINER Steven|   Bahamas|   1|     0|     0|    1|        [Men's 400m]|   2|
# |  GEZAHEGNE Kalkidan|   Bahrain|   0|     1|     0|    1|   [Women's 10,000m]|   1|
# |    LITVINOVICH Ivan|   Belarus|   1|     0|     0|    1|               [Men]|   1|
# |KADZIMAHAMEDAU Ma...|   Belarus|   0|     1|     0|    1|[Men's Freestyle ...|   2|
# +--------------------+----------+----+------+------+-----+--------------------+----+
# only showing top 20 rows
